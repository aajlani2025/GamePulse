# %% [markdown]
# Cell 1 : code to flatten the output of the imu json file

# %%
import json
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import defaultdict

IMU_SAMPLE_RATE = 52
DT = 1.0 / IMU_SAMPLE_RATE

# Physical sensor limits (from IMU specifications)
SENSOR_LIMITS = {
    # Accelerometer: ±16 g = ±156.96 m/s²
    # Typical Movesense IMU range
    'ax': (-156.96, 156.96),  # m/s²
    'ay': (-156.96, 156.96),
    'az': (-156.96, 156.96),

    # Gyroscope: ±1000°/s (Movesense default)
    'gx': (-1000, 1000),      # °/s
    'gy': (-1000, 1000),
    'gz': (-1000, 1000),
}

def flatten_movesense_imu_repeat(raw_json, fatigue_level, remove_outliers=True):
    """
    Flatten IMU JSON packets into rows and attach the given fatigue level.
    Now with outlier detection and removal based on sensor limits.
    """
    rows = []
    skipped_packets = 0
    repeated_rows_count = 0

    # Outlier counters
    acc_outliers = 0
    gyro_outliers = 0
    total_rows_processed = 0

    packets = raw_json.get("data", [])
    first_packet_timestamp_s = None

    for packet in packets:
        imu = packet.get("imu")
        if not imu:
            skipped_packets += 1
            continue

        timestamp_ms = imu.get("Timestamp")
        acc_list = imu.get("ArrayAcc", [])
        gyro_list = imu.get("ArrayGyro", [])

        if timestamp_ms is None or not acc_list or not gyro_list:
            skipped_packets += 1
            continue

        packet_timestamp_s = timestamp_ms / 1000.0

        if first_packet_timestamp_s is None:
            first_packet_timestamp_s = packet_timestamp_s

        packet_timestamp_s -= first_packet_timestamp_s

        len_acc = len(acc_list)
        len_gyro = len(gyro_list)
        n_samples = max(len_acc, len_gyro)

        last_row = None

        for i in range(n_samples):
            total_rows_processed += 1

            # Gyro
            if i < len_gyro:
                g = gyro_list[i]
                gx = float(g.get("x", 0.0))
                gy = float(g.get("y", 0.0))
                gz = float(g.get("z", 0.0))
            else:
                gx, gy, gz = last_row["gx"], last_row["gy"], last_row["gz"]

            # Acc
            if i < len_acc:
                a = acc_list[i]
                ax = float(a.get("x", 0.0))
                ay = float(a.get("y", 0.0))
                az = float(a.get("z", 0.0))
            else:
                ax, ay, az = last_row["ax"], last_row["ay"], last_row["az"]

            # Check for sensor limit outliers
            is_outlier = False

            # 1. Check individual sensor limits
            if ax < SENSOR_LIMITS['ax'][0] or ax > SENSOR_LIMITS['ax'][1]:
                acc_outliers += 1
                is_outlier = True

            if ay < SENSOR_LIMITS['ay'][0] or ay > SENSOR_LIMITS['ay'][1]:
                acc_outliers += 1
                is_outlier = True

            if az < SENSOR_LIMITS['az'][0] or az > SENSOR_LIMITS['az'][1]:
                acc_outliers += 1
                is_outlier = True

            if gx < SENSOR_LIMITS['gx'][0] or gx > SENSOR_LIMITS['gx'][1]:
                gyro_outliers += 1
                is_outlier = True

            if gy < SENSOR_LIMITS['gy'][0] or gy > SENSOR_LIMITS['gy'][1]:
                gyro_outliers += 1
                is_outlier = True

            if gz < SENSOR_LIMITS['gz'][0] or gz > SENSOR_LIMITS['gz'][1]:
                gyro_outliers += 1
                is_outlier = True

            # Skip this row if it's an outlier and we're removing outliers
            if is_outlier and remove_outliers:
                continue

            sample_timestamp = packet_timestamp_s + i * DT

            current_row = {
                "timestamp_s": round(sample_timestamp, 6),
                "gx": gx,
                "gy": gy,
                "gz": gz,
                "ax": ax,
                "ay": ay,
                "az": az,
                "fatigue_level": fatigue_level
            }

            rows.append(current_row)
            last_row = current_row

            if i >= len_acc or i >= len_gyro:
                repeated_rows_count += 1

    # Calculate statistics
    total_outliers = acc_outliers + gyro_outliers

    return rows, skipped_packets, repeated_rows_count, {
        'total_rows_processed': total_rows_processed,
        'total_outliers': total_outliers,
        'acc_outliers': acc_outliers,
        'gyro_outliers': gyro_outliers,
        'outlier_percentage': (total_outliers / total_rows_processed * 100) if total_rows_processed > 0 else 0
    }


def process_json(input_json_path, output_csv_path, fatigue_level, remove_outliers=True):
    """
    Process a raw IMU JSON file and export a flattened CSV with fatigue level.
    Now includes outlier detection and optional removal.
    """
    with open(input_json_path, "r") as f:
        raw_json = json.load(f)

    flattened_rows, skipped_packets, repeated_rows_count, outlier_stats = \
        flatten_movesense_imu_repeat(raw_json, fatigue_level, remove_outliers)

    print(f"\n{'='*60}")
    print(f"Processing: {input_json_path} (Fatigue Level: {fatigue_level})")
    print(f"{'='*60}")

    print(f"• Skipped packets: {skipped_packets}")
    print(f"• Repeated rows (unequal arrays): {repeated_rows_count}")
    print(f"• Total rows processed: {outlier_stats['total_rows_processed']}")
    print(f"• Rows saved to CSV: {len(flattened_rows)}")

    print(f"\nOutlier Detection Results:")
    print(f"• Total outliers detected: {outlier_stats['total_outliers']}")
    print(f"• Outlier percentage: {outlier_stats['outlier_percentage']:.2f}%")
    print(f"• Accelerometer outliers: {outlier_stats['acc_outliers']}")
    print(f"• Gyroscope outliers: {outlier_stats['gyro_outliers']}")

    if remove_outliers:
        print(f"• Outliers removed: {outlier_stats['total_outliers']}")
        print(f"• Clean rows remaining: {len(flattened_rows)}")
    else:
        print(f"• Outliers flagged but not removed")

    # Save to CSV - WITHOUT is_outlier and outlier_reasons columns
    with open(output_csv_path, "w", newline="") as f:
        writer = csv.DictWriter(
            f,
            fieldnames=["timestamp_s", "gx", "gy", "gz", "ax", "ay", "az", "fatigue_level"]
        )
        writer.writeheader()
        writer.writerows(flattened_rows)

    print(f"\n✓ Saved clean CSV: {output_csv_path}")

    return outlier_stats


def analyze_sensor_statistics(input_json_path, fatigue_level):
    """
    Analyze sensor statistics without saving CSV
    """
    with open(input_json_path, "r") as f:
        raw_json = json.load(f)

    # Process without removing outliers to analyze them
    rows, _, _, stats = flatten_movesense_imu_repeat(raw_json, fatigue_level, remove_outliers=False)

    # Calculate additional statistics
    if rows:
        # Extract sensor values
        ax_vals = [row['ax'] for row in rows]
        ay_vals = [row['ay'] for row in rows]
        az_vals = [row['az'] for row in rows]
        gx_vals = [row['gx'] for row in rows]
        gy_vals = [row['gy'] for row in rows]
        gz_vals = [row['gz'] for row in rows]

        print(f"\n{'='*60}")
        print(f"Sensor Statistics: {input_json_path}")
        print(f"{'='*60}")

        print(f"\nAccelerometer (m/s²):")
        print(f"  ax: min={min(ax_vals):.2f}, max={max(ax_vals):.2f}, mean={np.mean(ax_vals):.2f}")
        print(f"  ay: min={min(ay_vals):.2f}, max={max(ay_vals):.2f}, mean={np.mean(ay_vals):.2f}")
        print(f"  az: min={min(az_vals):.2f}, max={max(az_vals):.2f}, mean={np.mean(az_vals):.2f}")

        print(f"\nGyroscope (°/s):")
        print(f"  gx: min={min(gx_vals):.2f}, max={max(gx_vals):.2f}, mean={np.mean(gx_vals):.2f}")
        print(f"  gy: min={min(gy_vals):.2f}, max={max(gy_vals):.2f}, mean={np.mean(gy_vals):.2f}")
        print(f"  gz: min={min(gz_vals):.2f}, max={max(gz_vals):.2f}, mean={np.mean(gz_vals):.2f}")

        # Check for sensor saturation
        print(f"\nSensor Saturation Check:")
        for sensor, values, limit in [('ax', ax_vals, 156.96), ('ay', ay_vals, 156.96), ('az', az_vals, 156.96),
                                      ('gx', gx_vals, 1000), ('gy', gy_vals, 1000), ('gz', gz_vals, 1000)]:
            near_limit = sum(1 for v in values if abs(v) > limit * 0.95)  # Within 5% of limit
            if near_limit > 0:
                print(f"  {sensor}: {near_limit} values near saturation ({near_limit/len(values)*100:.1f}%)")

    return stats

# Process all files with outlier removal
print("="*70)
print("IMU DATA PROCESSING WITH OUTLIER DETECTION AND REMOVAL")
print("="*70)

total_stats = {
    'total_rows_processed': 0,
    'total_outliers': 0,
    'acc_outliers': 0,
    'gyro_outliers': 0,
}

# First, analyze statistics
print("\n" + "="*70)
print("ANALYZING SENSOR STATISTICS (Outliers flagged but not removed)")
print("="*70)

files_to_process = [
    ("imu_level0.json", "flattened_imu_output_level0.csv", 0),
    ("imu_level1.json", "flattened_imu_output_level1.csv", 1),
    ("imu_level2.json", "flattened_imu_output_level2.csv", 2),
    ("imu_level3.json", "flattened_imu_output_level3.csv", 3)
]

for input_file, output_file, fatigue_level in files_to_process:
    try:
        print(f"\nAnalyzing {input_file}...")
        stats = analyze_sensor_statistics(input_file, fatigue_level)

        # Accumulate statistics
        for key in total_stats.keys():
            total_stats[key] += stats[key]

    except FileNotFoundError:
        print(f"  File not found: {input_file}")
    except Exception as e:
        print(f"  Error analyzing {input_file}: {e}")

# Now process with outlier removal
print("\n" + "="*70)
print("PROCESSING WITH OUTLIER REMOVAL")
print("="*70)

all_processing_stats = []

for input_file, output_file, fatigue_level in files_to_process:
    try:
        stats = process_json(input_file, output_file, fatigue_level, remove_outliers=True)
        all_processing_stats.append({
            'file': input_file,
            'level': fatigue_level,
            'stats': stats
        })
    except FileNotFoundError:
        print(f"\nFile not found: {input_file}")
    except Exception as e:
        print(f"\nError processing {input_file}: {e}")

# Print comprehensive summary
print("\n" + "="*70)
print("COMPREHENSIVE OUTLIER SUMMARY")
print("="*70)

print(f"\n{'File':<30} {'Level':<8} {'Total Rows':<12} {'Outliers':<12} {'% Outliers':<12}")
print("-" * 90)

for item in all_processing_stats:
    stats = item['stats']
    print(f"{item['file']:<30} {item['level']:<8} {stats['total_rows_processed']:<12} "
          f"{stats['total_outliers']:<12} {stats['outlier_percentage']:<12.2f}")

print("-" * 90)

if total_stats['total_rows_processed'] > 0:
    overall_outlier_pct = (total_stats['total_outliers'] / total_stats['total_rows_processed']) * 100

    print(f"\nOVERALL TOTALS:")
    print(f"• Total rows processed: {total_stats['total_rows_processed']}")
    print(f"• Total outliers detected: {total_stats['total_outliers']}")
    print(f"• Overall outlier percentage: {overall_outlier_pct:.2f}%")
    print(f"\nBreakdown by type:")
    print(f"  • Accelerometer outliers: {total_stats['acc_outliers']}")
    print(f"  • Gyroscope outliers: {total_stats['gyro_outliers']}")

    # Recommendations
    print(f"\nRECOMMENDATIONS:")
    if overall_outlier_pct > 10:
        print("⚠️  High outlier rate (>10%). Consider:")
        print("   • Checking sensor placement and calibration")
        print("   • Reviewing data collection environment")
        print("   • Applying additional filtering in preprocessing")
    elif overall_outlier_pct > 5:
        print("⚠️  Moderate outlier rate (5-10%). Standard filtering applied.")
    else:
        print("✓ Good data quality (<5% outliers).")

# Create a summary CSV file
summary_csv = "imu_processing_summary.csv"
with open(summary_csv, "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=[
        'file', 'fatigue_level', 'total_rows', 'outliers_detected',
        'outlier_percentage', 'acc_outliers', 'gyro_outliers',
    ])
    writer.writeheader()

    for item in all_processing_stats:
        stats = item['stats']
        writer.writerow({
            'file': item['file'],
            'fatigue_level': item['level'],
            'total_rows': stats['total_rows_processed'],
            'outliers_detected': stats['total_outliers'],
            'outlier_percentage': stats['outlier_percentage'],
            'acc_outliers': stats['acc_outliers'],
            'gyro_outliers': stats['gyro_outliers'],
        })

print(f"\n✓ Processing summary saved to: {summary_csv}")
print("\n" + "="*70)
print("PROCESSING COMPLETE!")
print("="*70)
# Out:
# ======================================================================
# IMU DATA PROCESSING WITH OUTLIER DETECTION AND REMOVAL
# ======================================================================
#
# ======================================================================
# ANALYZING SENSOR STATISTICS (Outliers flagged but not removed)
# ======================================================================
#
# Analyzing imu_level0.json...
#
# ============================================================
# Sensor Statistics: imu_level0.json
# ============================================================
#
# Accelerometer (m/s²):
#   ax: min=2.25, max=6.77, mean=5.27
#   ay: min=-10.35, max=0.00, mean=-8.41
#   az: min=-2.35, max=1.53, mean=-0.18
#
# Gyroscope (°/s):
#   gx: min=-31.50, max=24.57, mean=1.13
#   gy: min=-28.21, max=29.47, mean=-2.09
#   gz: min=-26.74, max=33.67, mean=-0.95
#
# Sensor Saturation Check:
#
# Analyzing imu_level1.json...
#
# ============================================================
# Sensor Statistics: imu_level1.json
# ============================================================
#
# Accelerometer (m/s²):
#   ax: min=-28.82, max=23.96, mean=1.07
#   ay: min=-52.53, max=5.10, mean=-9.84
#   az: min=-15.36, max=9.35, mean=0.30
#
# Gyroscope (°/s):
#   gx: min=-238.35, max=109.41, mean=0.39
#   gy: min=-206.29, max=215.60, mean=-2.69
#   gz: min=-116.48, max=62.93, mean=-1.46
#
# Sensor Saturation Check:
#
# Analyzing imu_level2.json...
#
# ============================================================
# Sensor Statistics: imu_level2.json
# ============================================================
#
# Accelerometer (m/s²):
#   ax: min=-28.87, max=30.74, mean=-1.84
#   ay: min=-17.84, max=78.37, mean=9.36
#   az: min=-43.37, max=15.22, mean=0.57
#
# Gyroscope (°/s):
#   gx: min=-291.06, max=611.59, mean=0.90
#   gy: min=-243.04, max=239.33, mean=2.23
#   gz: min=-186.83, max=113.68, mean=-0.52
#
# Sensor Saturation Check:
#
# Analyzing imu_level3.json...
#
# ============================================================
# Sensor Statistics: imu_level3.json
# ============================================================
#
# Accelerometer (m/s²):
#   ax: min=-36.36, max=36.98, mean=-1.79
#   ay: min=-15.78, max=75.93, mean=9.28
#   az: min=-44.31, max=18.01, mean=0.51
#
# Gyroscope (°/s):
#   gx: min=-216.72, max=545.44, mean=0.62
#   gy: min=-242.20, max=266.84, mean=1.87
#   gz: min=-222.81, max=132.02, mean=-0.89
#
# Sensor Saturation Check:
#
# ======================================================================
# PROCESSING WITH OUTLIER REMOVAL
# ======================================================================
#
# ============================================================
# Processing: imu_level0.json (Fatigue Level: 0)
# ============================================================
# • Skipped packets: 1
# • Repeated rows (unequal arrays): 1
# • Total rows processed: 33588
# • Rows saved to CSV: 33588
#
# Outlier Detection Results:
# • Total outliers detected: 0
# • Outlier percentage: 0.00%
# • Accelerometer outliers: 0
# • Gyroscope outliers: 0
# • Outliers removed: 0
# • Clean rows remaining: 33588
#
# ✓ Saved clean CSV: flattened_imu_output_level0.csv
#
# ============================================================
# Processing: imu_level1.json (Fatigue Level: 1)
# ============================================================
# • Skipped packets: 0
# • Repeated rows (unequal arrays): 0
# • Total rows processed: 45012
# • Rows saved to CSV: 45012
#
# Outlier Detection Results:
# • Total outliers detected: 0
# • Outlier percentage: 0.00%
# • Accelerometer outliers: 0
# • Gyroscope outliers: 0
# • Outliers removed: 0
# • Clean rows remaining: 45012
#
# ✓ Saved clean CSV: flattened_imu_output_level1.csv
#
# ============================================================
# Processing: imu_level2.json (Fatigue Level: 2)
# ============================================================
# • Skipped packets: 0
# • Repeated rows (unequal arrays): 0
# • Total rows processed: 30104
# • Rows saved to CSV: 30104
#
# Outlier Detection Results:
# • Total outliers detected: 0
# • Outlier percentage: 0.00%
# • Accelerometer outliers: 0
# • Gyroscope outliers: 0
# • Outliers removed: 0
# • Clean rows remaining: 30104
#
# ✓ Saved clean CSV: flattened_imu_output_level2.csv
#
# ============================================================
# Processing: imu_level3.json (Fatigue Level: 3)
# ============================================================
# • Skipped packets: 0
# • Repeated rows (unequal arrays): 0
# • Total rows processed: 12840
# • Rows saved to CSV: 12840
#
# Outlier Detection Results:
# • Total outliers detected: 0
# • Outlier percentage: 0.00%
# • Accelerometer outliers: 0
# • Gyroscope outliers: 0
# • Outliers removed: 0
# • Clean rows remaining: 12840
#
# ✓ Saved clean CSV: flattened_imu_output_level3.csv
#
# ======================================================================
# COMPREHENSIVE OUTLIER SUMMARY
# ======================================================================
#
# File                           Level    Total Rows   Outliers     % Outliers
# ------------------------------------------------------------------------------------------
# imu_level0.json                0        33588        0            0.00
# imu_level1.json                1        45012        0            0.00
# imu_level2.json                2        30104        0            0.00
# imu_level3.json                3        12840        0            0.00
# ------------------------------------------------------------------------------------------
#
# OVERALL TOTALS:
# • Total rows processed: 121544
# • Total outliers detected: 0
# • Overall outlier percentage: 0.00%
#
# Breakdown by type:
#   • Accelerometer outliers: 0
#   • Gyroscope outliers: 0
#
# RECOMMENDATIONS:
# ✓ Good data quality (<5% outliers).
#
# ✓ Processing summary saved to: imu_processing_summary.csv
#
# ======================================================================
# PROCESSING COMPLETE!
# ======================================================================

# %% [markdown]
# Cell 2 : Adding the Acc Mag feature

# %%
def add_acceleration_magnitude(input_csv, output_csv):
    """
    Reads a CSV with columns ax, ay, az (IMU accelerometer),
    computes acceleration magnitude for each row, and saves a new CSV.

    Parameters:
        input_csv (str): path to input CSV
        output_csv (str): path to save output CSV
    """
    # Read CSV
    df = pd.read_csv(input_csv, sep=None, engine='python')  # auto-detect separator

    # Check columns
    required_cols = ['ax', 'ay', 'az']
    for col in required_cols:
        if col not in df.columns:
            raise ValueError(f"Input CSV must contain column '{col}'")

    # Compute acceleration magnitude
    df['acc_mag'] = np.sqrt(df['ax']**2 + df['ay']**2 + df['az']**2)

    # Save new CSV
    df.to_csv(output_csv, index=False)
    print(f"Saved new CSV with acceleration magnitude to {output_csv}")

# Example usage
add_acceleration_magnitude("flattened_imu_output_level0.csv", "imu_with_acc_mag_level0.csv")
add_acceleration_magnitude("flattened_imu_output_level1.csv", "imu_with_acc_mag_level1.csv")
add_acceleration_magnitude("flattened_imu_output_level2.csv", "imu_with_acc_mag_level2.csv")
add_acceleration_magnitude("flattened_imu_output_level3.csv", "imu_with_acc_mag_level3.csv")
# Out:
# Saved new CSV with acceleration magnitude to imu_with_acc_mag_level0.csv
# Saved new CSV with acceleration magnitude to imu_with_acc_mag_level1.csv
# Saved new CSV with acceleration magnitude to imu_with_acc_mag_level2.csv
# Saved new CSV with acceleration magnitude to imu_with_acc_mag_level3.csv

# %% [markdown]
# Cell 3 : Flattening the heart rate json

# %%
import json
import csv

def process_heart_rate_json_multiple_rr_seconds(input_json_file, output_csv_file):
    """
    Converts Movesense heart rate JSON into a CSV with:
    timestamp_s, average, rr_s

    - Each RR in rrData array becomes a separate line.
    - Timestamp is cumulative sum of RR intervals (in seconds).
    - RR is also converted to seconds.
    - If HR is missing but RR present, use last HR value.
    - If RR is missing but HR present, repeat last RR interval for timestamp increment.
    - If both are missing, discard.
    - Filters outliers based on specs:
        Heart rate: 20-240 BPM
        R-R intervals: 200-2000ms (0.2-2.0s)
    """
    with open(input_json_file, "r") as f:
        raw_data = json.load(f)

    rows = []
    cumulative_rr_ms = 0
    last_hr_avg = None
    last_rr_ms = None

    # Counters for statistics
    total_entries = 0
    hr_outliers_removed = 0
    rr_outliers_removed = 0

    for entry in raw_data.get("data", []):
        hr = entry.get("heartRate", {})

        avg = hr.get("average", None)
        rr_array = hr.get("rrData", [])

        # Skip entry if both HR and RR are missing
        if avg is None and not rr_array:
            continue

        # Use last HR if missing
        if avg is None:
            avg = last_hr_avg

        # Filter heart rate outliers (20-240 BPM)
        if avg is not None:
            total_entries += 1
            if avg < 20 or avg > 240:
                hr_outliers_removed += 1
                avg = None  # Mark as outlier

        # Filter RR intervals in the array (200-2000ms)
        filtered_rr_array = []
        for rr_ms in rr_array:
            if rr_ms >= 200 and rr_ms <= 2000:
                filtered_rr_array.append(rr_ms)
            else:
                rr_outliers_removed += 1

        # If after filtering, RR array is empty but we had valid RR before
        if not filtered_rr_array and last_rr_ms is not None:
            # Only use last RR if it was valid
            if last_rr_ms >= 200 and last_rr_ms <= 2000:
                filtered_rr_array = [last_rr_ms]
            else:
                # Last RR was also invalid, skip this entry
                continue

        # Skip if both HR and RR are invalid after filtering
        if avg is None and not filtered_rr_array:
            continue

        # Process filtered RR intervals
        for rr_ms in filtered_rr_array:
            cumulative_rr_ms += rr_ms
            row = {
                "timestamp_s": cumulative_rr_ms / 1000.0,
                "average": avg,
                "rr_s": rr_ms / 1000.0
            }
            rows.append(row)
            last_rr_ms = rr_ms

        last_hr_avg = avg

    # Save to CSV
    with open(output_csv_file, "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=["timestamp_s", "average", "rr_s"])
        writer.writeheader()
        writer.writerows(rows)

    print(f"Heart rate CSV saved to: {output_csv_file}")
    print(f"  Total entries processed: {total_entries}")
    print(f"  HR outliers removed (<20 or >240 BPM): {hr_outliers_removed}")
    print(f"  RR outliers removed (<200ms or >2000ms): {rr_outliers_removed}")
    print(f"  Valid entries written: {len(rows)}")

# Run processing
process_heart_rate_json_multiple_rr_seconds("hr_level0.json", "hr_flattened_level0.csv")
process_heart_rate_json_multiple_rr_seconds("hr_level1.json", "hr_flattened_level1.csv")
process_heart_rate_json_multiple_rr_seconds("hr_level2.json", "hr_flattened_level2.csv")
process_heart_rate_json_multiple_rr_seconds("hr_level3.json", "hr_flattened_level3.csv")  # Fixed filename
# Out:
# Heart rate CSV saved to: hr_flattened_level0.csv
#   Total entries processed: 923
#   HR outliers removed (<20 or >240 BPM): 0
#   RR outliers removed (<200ms or >2000ms): 0
#   Valid entries written: 923
# Heart rate CSV saved to: hr_flattened_level1.csv
#   Total entries processed: 1654
#   HR outliers removed (<20 or >240 BPM): 0
#   RR outliers removed (<200ms or >2000ms): 8
#   Valid entries written: 1654
# Heart rate CSV saved to: hr_flattened_level2.csv
#   Total entries processed: 904
#   HR outliers removed (<20 or >240 BPM): 0
#   RR outliers removed (<200ms or >2000ms): 16
#   Valid entries written: 904
# Heart rate CSV saved to: hr_flattened_level3.csv
#   Total entries processed: 508
#   HR outliers removed (<20 or >240 BPM): 0
#   RR outliers removed (<200ms or >2000ms): 3
#   Valid entries written: 508

# %% [markdown]
# Cell 4 : Assigning imu data to the hr data

# %%
def assign_imu_to_hr(imu_csv, hr_csv, output_csv):
    """
    Assigns each IMU line to a HR window based on HR timestamps.

    Physiologically correct logic:
    IMU between HR[j-1] and HR[j] → assigned to HR[j]
    """
    # Load CSVs
    imu_df = pd.read_csv(imu_csv)
    hr_df = pd.read_csv(hr_csv)

    # Add HR id
    hr_df = hr_df.reset_index().rename(columns={'index': 'hr_id'})
    hr_df['hr_id'] += 0

    # Sort both by timestamp
    imu_df = imu_df.sort_values('timestamp_s').reset_index(drop=True)
    hr_df = hr_df.sort_values('timestamp_s').reset_index(drop=True)

    # Initialize hr_id in IMU
    imu_df['hr_id'] = -1  # -1 means not assigned

    hr_timestamps = hr_df['timestamp_s'].tolist()
    hr_ids = hr_df['hr_id'].tolist()

    # -----------------------------
    # Correct windowing:
    # IMU in (HR[j-1], HR[j]] → HR[j]
    # -----------------------------
    for i, imu_time in enumerate(imu_df['timestamp_s']):
        assigned_hr_id = -1

        # First HR: IMU <= HR[0]
        if imu_time <= hr_timestamps[0]:
            assigned_hr_id = hr_ids[0]
        else:
            # Search interval (HR[j-1], HR[j]]
            for j in range(1, len(hr_timestamps)):
                if hr_timestamps[j - 1] < imu_time <= hr_timestamps[j]:
                    assigned_hr_id = hr_ids[j]
                    break

        # If IMU_time > last HR timestamp → stays -1 (do NOT remove)
        imu_df.at[i, 'hr_id'] = assigned_hr_id

    # Count IMU lines per HR (ignoring -1)
    counts = imu_df[imu_df['hr_id'] != -1]['hr_id'].value_counts().sort_index()

    print("Number of IMU lines per HR id:")
    for hr_id in counts.index:
        print(f"HR id {hr_id}: {counts[hr_id]} IMU lines")

    # Exclude last HR id from average
    if len(counts) > 0 and counts.index[-1] == hr_ids[-1]:
        counts = counts[counts.index ]
        average_lines = counts.mean()
        print(f"\nAverage IMU lines per HR line: {average_lines:.2f}")
        print(f"HR id {counts.index[-1]} had {counts.iloc[-1]} IMU lines ")
    else:
        average_lines = counts.mean()
        print(f"\nAverage IMU lines per HR line: {average_lines:.2f}")

    # Save output (with hr_id = -1 still included)
    imu_df.to_csv(output_csv, index=False)
    print(f"\nSaved IMU CSV with hr_id to: {output_csv}")


assign_imu_to_hr("imu_with_acc_mag_level0.csv", "hr_flattened_level0.csv", "imu_hr_aligned_level0.csv")
assign_imu_to_hr("imu_with_acc_mag_level1.csv", "hr_flattened_level1.csv", "imu_hr_aligned_level1.csv")
assign_imu_to_hr("imu_with_acc_mag_level2.csv", "hr_flattened_level2.csv", "imu_hr_aligned_level2.csv")
assign_imu_to_hr("imu_with_acc_mag_level3.csv", "hr_flattened_level3.csv", "imu_hr_aligned_level3.csv")
# Out:
# Number of IMU lines per HR id:
# HR id 0: 50 IMU lines
# HR id 1: 48 IMU lines
# HR id 2: 49 IMU lines
# HR id 3: 49 IMU lines
# HR id 4: 47 IMU lines
# HR id 5: 49 IMU lines
# HR id 6: 48 IMU lines
# HR id 7: 48 IMU lines
# HR id 8: 49 IMU lines
# HR id 9: 49 IMU lines
# HR id 10: 50 IMU lines
# HR id 11: 49 IMU lines
# HR id 12: 48 IMU lines
# HR id 13: 49 IMU lines
# HR id 14: 49 IMU lines
# HR id 15: 49 IMU lines
# HR id 16: 48 IMU lines
# HR id 17: 48 IMU lines
# HR id 18: 47 IMU lines
# HR id 19: 47 IMU lines
# HR id 20: 46 IMU lines
# HR id 21: 49 IMU lines
# HR id 22: 55 IMU lines
# HR id 23: 50 IMU lines
# HR id 24: 50 IMU lines
# HR id 25: 50 IMU lines
# HR id 26: 50 IMU lines
# HR id 27: 49 IMU lines
# HR id 28: 49 IMU lines
# HR id 29: 50 IMU lines
# HR id 30: 50 IMU lines
# HR id 31: 51 IMU lines
# HR id 32: 51 IMU lines
# HR id 33: 49 IMU lines
# HR id 34: 51 IMU lines
# HR id 35: 53 IMU lines
# HR id 36: 51 IMU lines
# HR id 37: 50 IMU lines
# HR id 38: 51 IMU lines
# HR id 39: 51 IMU lines
# HR id 40: 50 IMU lines
# HR id 41: 50 IMU lines
# HR id 42: 49 IMU lines
# HR id 43: 50 IMU lines
# HR id 44: 51 IMU lines
# HR id 45: 50 IMU lines
# HR id 46: 49 IMU lines
# HR id 47: 50 IMU lines
# HR id 48: 50 IMU lines
# HR id 49: 50 IMU lines
# HR id 50: 49 IMU lines
# HR id 51: 50 IMU lines
# HR id 52: 48 IMU lines
# HR id 53: 50 IMU lines
# HR id 54: 47 IMU lines
# HR id 55: 49 IMU lines
# HR id 56: 50 IMU lines
# HR id 57: 48 IMU lines
# HR id 58: 49 IMU lines
# HR id 59: 49 IMU lines
# HR id 60: 48 IMU lines
# HR id 61: 50 IMU lines
# HR id 62: 48 IMU lines
# HR id 63: 50 IMU lines
# HR id 64: 49 IMU lines
# HR id 65: 49 IMU lines
# HR id 66: 49 IMU lines
# HR id 67: 49 IMU lines
# HR id 68: 49 IMU lines
# HR id 69: 49 IMU lines
# HR id 70: 48 IMU lines
# HR id 71: 50 IMU lines
# HR id 72: 49 IMU lines
# HR id 73: 50 IMU lines
# HR id 74: 49 IMU lines
# HR id 75: 49 IMU lines
# HR id 76: 48 IMU lines
# HR id 77: 50 IMU lines
# HR id 78: 48 IMU lines
# HR id 79: 49 IMU lines
# HR id 80: 49 IMU lines
# HR id 81: 48 IMU lines
# HR id 82: 49 IMU lines
# HR id 83: 48 IMU lines
# HR id 84: 48 IMU lines
# HR id 85: 49 IMU lines
# HR id 86: 49 IMU lines
# HR id 87: 48 IMU lines
# HR id 88: 49 IMU lines
# HR id 89: 49 IMU lines
# HR id 90: 49 IMU lines
# HR id 91: 49 IMU lines
# HR id 92: 49 IMU lines
# HR id 93: 48 IMU lines
# HR id 94: 49 IMU lines
# HR id 95: 49 IMU lines
# HR id 96: 49 IMU lines
# HR id 97: 48 IMU lines
# HR id 98: 48 IMU lines
# HR id 99: 48 IMU lines
# HR id 100: 50 IMU lines
# HR id 101: 49 IMU lines
# HR id 102: 50 IMU lines
# HR id 103: 49 IMU lines
# HR id 104: 49 IMU lines
# HR id 105: 47 IMU lines
# HR id 106: 50 IMU lines
# HR id 107: 48 IMU lines
# HR id 108: 48 IMU lines
# HR id 109: 49 IMU lines
# HR id 110: 48 IMU lines
# HR id 111: 48 IMU lines
# HR id 112: 49 IMU lines
# HR id 113: 48 IMU lines
# HR id 114: 48 IMU lines
# HR id 115: 49 IMU lines
# HR id 116: 48 IMU lines
# HR id 117: 47 IMU lines
# HR id 118: 49 IMU lines
# HR id 119: 48 IMU lines
# HR id 120: 49 IMU lines
# HR id 121: 47 IMU lines
# HR id 122: 46 IMU lines
# HR id 123: 47 IMU lines
# HR id 124: 47 IMU lines
# HR id 125: 47 IMU lines
# HR id 126: 48 IMU lines
# HR id 127: 48 IMU lines
# HR id 128: 48 IMU lines
# HR id 129: 48 IMU lines
# HR id 130: 47 IMU lines
# HR id 131: 47 IMU lines
# HR id 132: 47 IMU lines
# HR id 133: 49 IMU lines
# HR id 134: 47 IMU lines
# HR id 135: 47 IMU lines
# HR id 136: 49 IMU lines
# HR id 137: 49 IMU lines
# HR id 138: 49 IMU lines
# HR id 139: 50 IMU lines
# HR id 140: 53 IMU lines
# HR id 141: 52 IMU lines
# HR id 142: 51 IMU lines
# HR id 143: 51 IMU lines
# HR id 144: 50 IMU lines
# HR id 145: 50 IMU lines
# HR id 146: 50 IMU lines
# HR id 147: 49 IMU lines
# HR id 148: 50 IMU lines
# HR id 149: 51 IMU lines
# HR id 150: 50 IMU lines
# HR id 151: 49 IMU lines
# HR id 152: 52 IMU lines
# HR id 153: 51 IMU lines
# HR id 154: 50 IMU lines
# HR id 155: 49 IMU lines
# HR id 156: 50 IMU lines
# HR id 157: 50 IMU lines
# HR id 158: 49 IMU lines
# HR id 159: 50 IMU lines
# HR id 160: 50 IMU lines
# HR id 161: 50 IMU lines
# HR id 162: 49 IMU lines
# HR id 163: 50 IMU lines
# HR id 164: 50 IMU lines
# HR id 165: 49 IMU lines
# HR id 166: 50 IMU lines
# HR id 167: 49 IMU lines
# HR id 168: 50 IMU lines
# HR id 169: 49 IMU lines
# HR id 170: 50 IMU lines
# HR id 171: 50 IMU lines
# HR id 172: 49 IMU lines
# HR id 173: 49 IMU lines
# HR id 174: 49 IMU lines
# HR id 175: 49 IMU lines
# HR id 176: 48 IMU lines
# HR id 177: 50 IMU lines
# HR id 178: 49 IMU lines
# HR id 179: 49 IMU lines
# HR id 180: 48 IMU lines
# HR id 181: 49 IMU lines
# HR id 182: 49 IMU lines
# HR id 183: 49 IMU lines
# HR id 184: 49 IMU lines
# HR id 185: 48 IMU lines
# HR id 186: 48 IMU lines
# HR id 187: 47 IMU lines
# HR id 188: 48 IMU lines
# HR id 189: 49 IMU lines
# HR id 190: 48 IMU lines
# HR id 191: 50 IMU lines
# HR id 192: 49 IMU lines
# HR id 193: 47 IMU lines
# HR id 194: 49 IMU lines
# HR id 195: 49 IMU lines
# HR id 196: 48 IMU lines
# HR id 197: 49 IMU lines
# HR id 198: 48 IMU lines
# HR id 199: 47 IMU lines
# HR id 200: 46 IMU lines
# HR id 201: 50 IMU lines
# HR id 202: 47 IMU lines
# HR id 203: 47 IMU lines
# HR id 204: 49 IMU lines
# HR id 205: 49 IMU lines
# HR id 206: 48 IMU lines
# HR id 207: 50 IMU lines
# HR id 208: 49 IMU lines
# HR id 209: 48 IMU lines
# HR id 210: 50 IMU lines
# HR id 211: 49 IMU lines
# HR id 212: 49 IMU lines
# HR id 213: 48 IMU lines
# HR id 214: 48 IMU lines
# HR id 215: 51 IMU lines
# HR id 216: 49 IMU lines
# HR id 217: 49 IMU lines
# HR id 218: 50 IMU lines
# HR id 219: 49 IMU lines
# HR id 220: 48 IMU lines
# HR id 221: 50 IMU lines
# HR id 222: 49 IMU lines
# HR id 223: 49 IMU lines
# HR id 224: 48 IMU lines
# HR id 225: 50 IMU lines
# HR id 226: 49 IMU lines
# HR id 227: 49 IMU lines
# HR id 228: 50 IMU lines
# HR id 229: 49 IMU lines
# HR id 230: 50 IMU lines
# HR id 231: 49 IMU lines
# HR id 232: 50 IMU lines
# HR id 233: 48 IMU lines
# HR id 234: 50 IMU lines
# HR id 235: 49 IMU lines
# HR id 236: 49 IMU lines
# HR id 237: 48 IMU lines
# HR id 238: 50 IMU lines
# HR id 239: 49 IMU lines
# HR id 240: 49 IMU lines
# HR id 241: 48 IMU lines
# HR id 242: 50 IMU lines
# HR id 243: 49 IMU lines
# HR id 244: 51 IMU lines
# HR id 245: 50 IMU lines
# HR id 246: 48 IMU lines
# HR id 247: 50 IMU lines
# HR id 248: 50 IMU lines
# HR id 249: 48 IMU lines
# HR id 250: 50 IMU lines
# HR id 251: 49 IMU lines
# HR id 252: 49 IMU lines
# HR id 253: 49 IMU lines
# HR id 254: 49 IMU lines
# HR id 255: 50 IMU lines
# HR id 256: 51 IMU lines
# HR id 257: 50 IMU lines
# HR id 258: 50 IMU lines
# HR id 259: 49 IMU lines
# HR id 260: 51 IMU lines
# HR id 261: 50 IMU lines
# HR id 262: 50 IMU lines
# HR id 263: 50 IMU lines
# HR id 264: 49 IMU lines
# HR id 265: 50 IMU lines
# HR id 266: 49 IMU lines
# HR id 267: 50 IMU lines
# HR id 268: 49 IMU lines
# HR id 269: 49 IMU lines
# HR id 270: 50 IMU lines
# HR id 271: 49 IMU lines
# HR id 272: 50 IMU lines
# HR id 273: 50 IMU lines
# HR id 274: 50 IMU lines
# HR id 275: 48 IMU lines
# HR id 276: 48 IMU lines
# HR id 277: 50 IMU lines
# HR id 278: 49 IMU lines
# HR id 279: 50 IMU lines
# HR id 280: 49 IMU lines
# HR id 281: 49 IMU lines
# HR id 282: 49 IMU lines
# HR id 283: 49 IMU lines
# HR id 284: 50 IMU lines
# HR id 285: 50 IMU lines
# HR id 286: 49 IMU lines
# HR id 287: 51 IMU lines
# HR id 288: 48 IMU lines
# HR id 289: 51 IMU lines
# HR id 290: 51 IMU lines
# HR id 291: 49 IMU lines
# HR id 292: 50 IMU lines
# HR id 293: 50 IMU lines
# HR id 294: 51 IMU lines
# HR id 295: 50 IMU lines
# HR id 296: 50 IMU lines
# HR id 297: 50 IMU lines
# HR id 298: 50 IMU lines
# HR id 299: 49 IMU lines
# HR id 300: 49 IMU lines
# HR id 301: 51 IMU lines
# HR id 302: 49 IMU lines
# HR id 303: 50 IMU lines
# HR id 304: 49 IMU lines
# HR id 305: 50 IMU lines
# HR id 306: 50 IMU lines
# HR id 307: 50 IMU lines
# HR id 308: 51 IMU lines
# HR id 309: 50 IMU lines
# HR id 310: 51 IMU lines
# HR id 311: 51 IMU lines
# HR id 312: 49 IMU lines
# HR id 313: 51 IMU lines
# HR id 314: 50 IMU lines
# HR id 315: 51 IMU lines
# HR id 316: 50 IMU lines
# HR id 317: 50 IMU lines
# HR id 318: 50 IMU lines
# HR id 319: 50 IMU lines
# HR id 320: 51 IMU lines
# HR id 321: 49 IMU lines
# HR id 322: 51 IMU lines
# HR id 323: 50 IMU lines
# HR id 324: 50 IMU lines
# HR id 325: 49 IMU lines
# HR id 326: 51 IMU lines
# HR id 327: 50 IMU lines
# HR id 328: 50 IMU lines
# HR id 329: 51 IMU lines
# HR id 330: 51 IMU lines
# HR id 331: 50 IMU lines
# HR id 332: 49 IMU lines
# HR id 333: 51 IMU lines
# HR id 334: 49 IMU lines
# HR id 335: 48 IMU lines
# HR id 336: 50 IMU lines
# HR id 337: 49 IMU lines
# HR id 338: 49 IMU lines
# HR id 339: 49 IMU lines
# HR id 340: 48 IMU lines
# HR id 341: 49 IMU lines
# HR id 342: 47 IMU lines
# HR id 343: 48 IMU lines
# HR id 344: 47 IMU lines
# HR id 345: 47 IMU lines
# HR id 346: 47 IMU lines
# HR id 347: 47 IMU lines
# HR id 348: 48 IMU lines
# HR id 349: 48 IMU lines
# HR id 350: 48 IMU lines
# HR id 351: 48 IMU lines
# HR id 352: 47 IMU lines
# HR id 353: 47 IMU lines
# HR id 354: 49 IMU lines
# HR id 355: 47 IMU lines
# HR id 356: 49 IMU lines
# HR id 357: 46 IMU lines
# HR id 358: 48 IMU lines
# HR id 359: 49 IMU lines
# HR id 360: 48 IMU lines
# HR id 361: 48 IMU lines
# HR id 362: 48 IMU lines
# HR id 363: 50 IMU lines
# HR id 364: 48 IMU lines
# HR id 365: 49 IMU lines
# HR id 366: 50 IMU lines
# HR id 367: 49 IMU lines
# HR id 368: 48 IMU lines
# HR id 369: 49 IMU lines
# HR id 370: 49 IMU lines
# HR id 371: 48 IMU lines
# HR id 372: 48 IMU lines
# HR id 373: 48 IMU lines
# HR id 374: 48 IMU lines
# HR id 375: 47 IMU lines
# HR id 376: 48 IMU lines
# HR id 377: 46 IMU lines
# HR id 378: 48 IMU lines
# HR id 379: 46 IMU lines
# HR id 380: 47 IMU lines
# HR id 381: 46 IMU lines
# HR id 382: 47 IMU lines
# HR id 383: 47 IMU lines
# HR id 384: 46 IMU lines
# HR id 385: 48 IMU lines
# HR id 386: 47 IMU lines
# HR id 387: 47 IMU lines
# HR id 388: 48 IMU lines
# HR id 389: 48 IMU lines
# HR id 390: 47 IMU lines
# HR id 391: 47 IMU lines
# HR id 392: 48 IMU lines
# HR id 393: 47 IMU lines
# HR id 394: 48 IMU lines
# HR id 395: 46 IMU lines
# HR id 396: 47 IMU lines
# HR id 397: 48 IMU lines
# HR id 398: 47 IMU lines
# HR id 399: 48 IMU lines
# HR id 400: 48 IMU lines
# HR id 401: 49 IMU lines
# HR id 402: 48 IMU lines
# HR id 403: 49 IMU lines
# HR id 404: 48 IMU lines
# HR id 405: 49 IMU lines
# HR id 406: 47 IMU lines
# HR id 407: 49 IMU lines
# HR id 408: 49 IMU lines
# HR id 409: 48 IMU lines
# HR id 410: 48 IMU lines
# HR id 411: 50 IMU lines
# HR id 412: 48 IMU lines
# HR id 413: 49 IMU lines
# HR id 414: 48 IMU lines
# HR id 415: 48 IMU lines
# HR id 416: 50 IMU lines
# HR id 417: 48 IMU lines
# HR id 418: 49 IMU lines
# HR id 419: 49 IMU lines
# HR id 420: 48 IMU lines
# HR id 421: 48 IMU lines
# HR id 422: 49 IMU lines
# HR id 423: 49 IMU lines
# HR id 424: 48 IMU lines
# HR id 425: 52 IMU lines
# HR id 426: 49 IMU lines
# HR id 427: 48 IMU lines
# HR id 428: 50 IMU lines
# HR id 429: 50 IMU lines
# HR id 430: 50 IMU lines
# HR id 431: 49 IMU lines
# HR id 432: 51 IMU lines
# HR id 433: 50 IMU lines
# HR id 434: 49 IMU lines
# HR id 435: 50 IMU lines
# HR id 436: 50 IMU lines
# HR id 437: 48 IMU lines
# HR id 438: 50 IMU lines
# HR id 439: 49 IMU lines
# HR id 440: 50 IMU lines
# HR id 441: 49 IMU lines
# HR id 442: 51 IMU lines
# HR id 443: 50 IMU lines
# HR id 444: 49 IMU lines
# HR id 445: 51 IMU lines
# HR id 446: 50 IMU lines
# HR id 447: 50 IMU lines
# HR id 448: 49 IMU lines
# HR id 449: 50 IMU lines
# HR id 450: 50 IMU lines
# HR id 451: 49 IMU lines
# HR id 452: 50 IMU lines
# HR id 453: 51 IMU lines
# HR id 454: 49 IMU lines
# HR id 455: 51 IMU lines
# HR id 456: 49 IMU lines
# HR id 457: 50 IMU lines
# HR id 458: 50 IMU lines
# HR id 459: 48 IMU lines
# HR id 460: 50 IMU lines
# HR id 461: 48 IMU lines
# HR id 462: 48 IMU lines
# HR id 463: 48 IMU lines
# HR id 464: 48 IMU lines
# HR id 465: 47 IMU lines
# HR id 466: 49 IMU lines
# HR id 467: 48 IMU lines
# HR id 468: 47 IMU lines
# HR id 469: 38 IMU lines
# HR id 708: 2 IMU lines
# HR id 709: 45 IMU lines
# HR id 710: 45 IMU lines
# HR id 711: 44 IMU lines
# HR id 712: 46 IMU lines
# HR id 713: 45 IMU lines
# HR id 714: 45 IMU lines
# HR id 715: 45 IMU lines
# HR id 716: 46 IMU lines
# HR id 717: 45 IMU lines
# HR id 718: 45 IMU lines
# HR id 719: 47 IMU lines
# HR id 720: 46 IMU lines
# HR id 721: 45 IMU lines
# HR id 722: 47 IMU lines
# HR id 723: 46 IMU lines
# HR id 724: 45 IMU lines
# HR id 725: 47 IMU lines
# HR id 726: 47 IMU lines
# HR id 727: 45 IMU lines
# HR id 728: 45 IMU lines
# HR id 729: 46 IMU lines
# HR id 730: 46 IMU lines
# HR id 731: 46 IMU lines
# HR id 732: 48 IMU lines
# HR id 733: 47 IMU lines
# HR id 734: 46 IMU lines
# HR id 735: 48 IMU lines
# HR id 736: 49 IMU lines
# HR id 737: 47 IMU lines
# HR id 738: 48 IMU lines
# HR id 739: 47 IMU lines
# HR id 740: 47 IMU lines
# HR id 741: 45 IMU lines
# HR id 742: 46 IMU lines
# HR id 743: 47 IMU lines
# HR id 744: 47 IMU lines
# HR id 745: 46 IMU lines
# HR id 746: 47 IMU lines
# HR id 747: 46 IMU lines
# HR id 748: 46 IMU lines
# HR id 749: 48 IMU lines
# HR id 750: 47 IMU lines
# HR id 751: 48 IMU lines
# HR id 752: 47 IMU lines
# HR id 753: 48 IMU lines
# HR id 754: 48 IMU lines
# HR id 755: 46 IMU lines
# HR id 756: 48 IMU lines
# HR id 757: 47 IMU lines
# HR id 758: 48 IMU lines
# HR id 759: 46 IMU lines
# HR id 760: 49 IMU lines
# HR id 761: 51 IMU lines
# HR id 762: 46 IMU lines
# HR id 763: 46 IMU lines
# HR id 764: 45 IMU lines
# HR id 765: 47 IMU lines
# HR id 766: 46 IMU lines
# HR id 767: 48 IMU lines
# HR id 768: 48 IMU lines
# HR id 769: 46 IMU lines
# HR id 770: 48 IMU lines
# HR id 771: 47 IMU lines
# HR id 772: 47 IMU lines
# HR id 773: 49 IMU lines
# HR id 774: 48 IMU lines
# HR id 775: 49 IMU lines
# HR id 776: 48 IMU lines
# HR id 777: 49 IMU lines
# HR id 778: 50 IMU lines
# HR id 779: 49 IMU lines
# HR id 780: 50 IMU lines
# HR id 781: 50 IMU lines
# HR id 782: 50 IMU lines
# HR id 783: 50 IMU lines
# HR id 784: 50 IMU lines
# HR id 785: 50 IMU lines
# HR id 786: 52 IMU lines
# HR id 787: 50 IMU lines
# HR id 788: 50 IMU lines
# HR id 789: 49 IMU lines
# HR id 790: 52 IMU lines
# HR id 791: 50 IMU lines
# HR id 792: 51 IMU lines
# HR id 793: 50 IMU lines
# HR id 794: 48 IMU lines
# HR id 795: 52 IMU lines
# HR id 796: 50 IMU lines
# HR id 797: 50 IMU lines
# HR id 798: 51 IMU lines
# HR id 799: 50 IMU lines
# HR id 800: 50 IMU lines
# HR id 801: 51 IMU lines
# HR id 802: 52 IMU lines
# HR id 803: 51 IMU lines
# HR id 804: 50 IMU lines
# HR id 805: 52 IMU lines
# HR id 806: 49 IMU lines
# HR id 807: 51 IMU lines
# HR id 808: 52 IMU lines
# HR id 809: 49 IMU lines
# HR id 810: 51 IMU lines
# HR id 811: 51 IMU lines
# HR id 812: 51 IMU lines
# HR id 813: 50 IMU lines
# HR id 814: 51 IMU lines
# HR id 815: 50 IMU lines
# HR id 816: 51 IMU lines
# HR id 817: 51 IMU lines
# HR id 818: 51 IMU lines
# HR id 819: 50 IMU lines
# HR id 820: 51 IMU lines
# HR id 821: 51 IMU lines
# HR id 822: 50 IMU lines
# HR id 823: 51 IMU lines
# HR id 824: 50 IMU lines
# HR id 825: 51 IMU lines
# HR id 826: 52 IMU lines
# HR id 827: 51 IMU lines
# HR id 828: 50 IMU lines
# HR id 829: 52 IMU lines
# HR id 830: 52 IMU lines
# HR id 831: 51 IMU lines
# HR id 832: 51 IMU lines
# HR id 833: 49 IMU lines
# HR id 834: 52 IMU lines
# HR id 835: 50 IMU lines
# HR id 836: 51 IMU lines
# HR id 837: 49 IMU lines
# HR id 838: 49 IMU lines
# HR id 839: 50 IMU lines
# HR id 840: 50 IMU lines
# HR id 841: 51 IMU lines
# HR id 842: 50 IMU lines
# HR id 843: 50 IMU lines
# HR id 844: 50 IMU lines
# HR id 845: 50 IMU lines
# HR id 846: 50 IMU lines
# HR id 847: 49 IMU lines
# HR id 848: 52 IMU lines
# HR id 849: 58 IMU lines
# HR id 850: 54 IMU lines
# HR id 851: 52 IMU lines
# HR id 852: 51 IMU lines
# HR id 853: 51 IMU lines
# HR id 854: 49 IMU lines
# HR id 855: 52 IMU lines
# HR id 856: 53 IMU lines
# HR id 857: 58 IMU lines
# HR id 858: 56 IMU lines
# HR id 859: 53 IMU lines
# HR id 860: 53 IMU lines
# HR id 861: 51 IMU lines
# HR id 862: 51 IMU lines
# HR id 863: 50 IMU lines
# HR id 864: 50 IMU lines
# HR id 865: 51 IMU lines
# HR id 866: 51 IMU lines
# HR id 867: 51 IMU lines
# HR id 868: 50 IMU lines
# HR id 869: 49 IMU lines
# HR id 870: 49 IMU lines
# HR id 871: 51 IMU lines
# HR id 872: 51 IMU lines
# HR id 873: 49 IMU lines
# HR id 874: 48 IMU lines
# HR id 875: 48 IMU lines
# HR id 876: 47 IMU lines
# HR id 877: 48 IMU lines
# HR id 878: 47 IMU lines
# HR id 879: 51 IMU lines
# HR id 880: 56 IMU lines
# HR id 881: 54 IMU lines
# HR id 882: 51 IMU lines
# HR id 883: 51 IMU lines
# HR id 884: 53 IMU lines
# HR id 885: 52 IMU lines
# HR id 886: 50 IMU lines
# HR id 887: 49 IMU lines
# HR id 888: 50 IMU lines
# HR id 889: 49 IMU lines
# HR id 890: 49 IMU lines
# HR id 891: 50 IMU lines
# HR id 892: 48 IMU lines
# HR id 893: 51 IMU lines
# HR id 894: 50 IMU lines
# HR id 895: 49 IMU lines
# HR id 896: 50 IMU lines
# HR id 897: 48 IMU lines
# HR id 898: 50 IMU lines
# HR id 899: 50 IMU lines
# HR id 900: 51 IMU lines
# HR id 901: 50 IMU lines
# HR id 902: 49 IMU lines
# HR id 903: 49 IMU lines
# HR id 904: 49 IMU lines
# HR id 905: 49 IMU lines
# HR id 906: 48 IMU lines
# HR id 907: 50 IMU lines
# HR id 908: 49 IMU lines
# HR id 909: 48 IMU lines
# HR id 910: 48 IMU lines
# HR id 911: 48 IMU lines
# HR id 912: 49 IMU lines
# HR id 913: 50 IMU lines
# HR id 914: 49 IMU lines
# HR id 915: 50 IMU lines
# HR id 916: 50 IMU lines
# HR id 917: 49 IMU lines
# HR id 918: 49 IMU lines
# HR id 919: 48 IMU lines
# HR id 920: 51 IMU lines
# HR id 921: 49 IMU lines
# HR id 922: 49 IMU lines
#
# Average IMU lines per HR line: 48.99
# HR id 922 had 49 IMU lines
#
# Saved IMU CSV with hr_id to: imu_hr_aligned_level0.csv
# Number of IMU lines per HR id:
# HR id 0: 30 IMU lines
# HR id 1: 32 IMU lines
# HR id 2: 32 IMU lines
# HR id 3: 30 IMU lines
# HR id 4: 16 IMU lines
# HR id 5: 20 IMU lines
# HR id 6: 40 IMU lines
# HR id 7: 41 IMU lines
# HR id 8: 36 IMU lines
# HR id 9: 16 IMU lines
# HR id 10: 16 IMU lines
# HR id 11: 23 IMU lines
# HR id 12: 14 IMU lines
# HR id 13: 21 IMU lines
# HR id 14: 16 IMU lines
# HR id 15: 18 IMU lines
# HR id 16: 14 IMU lines
# HR id 17: 29 IMU lines
# HR id 18: 19 IMU lines
# HR id 19: 35 IMU lines
# HR id 20: 18 IMU lines
# HR id 21: 24 IMU lines
# HR id 22: 37 IMU lines
# HR id 23: 15 IMU lines
# HR id 24: 19 IMU lines
# HR id 25: 19 IMU lines
# HR id 26: 20 IMU lines
# HR id 27: 42 IMU lines
# HR id 28: 17 IMU lines
# HR id 29: 17 IMU lines
# HR id 30: 79 IMU lines
# HR id 31: 18 IMU lines
# HR id 32: 15 IMU lines
# HR id 33: 78 IMU lines
# HR id 34: 20 IMU lines
# HR id 35: 77 IMU lines
# HR id 36: 51 IMU lines
# HR id 37: 40 IMU lines
# HR id 38: 54 IMU lines
# HR id 39: 33 IMU lines
# HR id 40: 19 IMU lines
# HR id 41: 16 IMU lines
# HR id 42: 60 IMU lines
# HR id 43: 60 IMU lines
# HR id 44: 30 IMU lines
# HR id 45: 41 IMU lines
# HR id 46: 40 IMU lines
# HR id 47: 41 IMU lines
# HR id 48: 38 IMU lines
# HR id 49: 32 IMU lines
# HR id 50: 75 IMU lines
# HR id 51: 38 IMU lines
# HR id 52: 54 IMU lines
# HR id 53: 17 IMU lines
# HR id 54: 16 IMU lines
# HR id 55: 19 IMU lines
# HR id 56: 55 IMU lines
# HR id 57: 16 IMU lines
# HR id 58: 38 IMU lines
# HR id 59: 22 IMU lines
# HR id 60: 50 IMU lines
# HR id 61: 36 IMU lines
# HR id 62: 36 IMU lines
# HR id 63: 71 IMU lines
# HR id 64: 34 IMU lines
# HR id 65: 37 IMU lines
# HR id 66: 38 IMU lines
# HR id 67: 49 IMU lines
# HR id 68: 19 IMU lines
# HR id 69: 17 IMU lines
# HR id 70: 38 IMU lines
# HR id 71: 34 IMU lines
# HR id 72: 36 IMU lines
# HR id 73: 21 IMU lines
# HR id 74: 91 IMU lines
# HR id 75: 31 IMU lines
# HR id 76: 41 IMU lines
# HR id 77: 37 IMU lines
# HR id 78: 18 IMU lines
# HR id 79: 13 IMU lines
# HR id 80: 75 IMU lines
# HR id 81: 35 IMU lines
# HR id 82: 36 IMU lines
# HR id 83: 39 IMU lines
# HR id 84: 30 IMU lines
# HR id 85: 43 IMU lines
# HR id 86: 36 IMU lines
# HR id 87: 33 IMU lines
# HR id 88: 38 IMU lines
# HR id 89: 54 IMU lines
# HR id 90: 13 IMU lines
# HR id 91: 20 IMU lines
# HR id 92: 92 IMU lines
# HR id 93: 32 IMU lines
# HR id 94: 22 IMU lines
# HR id 95: 35 IMU lines
# HR id 96: 15 IMU lines
# HR id 97: 21 IMU lines
# HR id 98: 17 IMU lines
# HR id 99: 36 IMU lines
# HR id 100: 17 IMU lines
# HR id 101: 20 IMU lines
# HR id 102: 17 IMU lines
# HR id 103: 37 IMU lines
# HR id 104: 66 IMU lines
# HR id 105: 20 IMU lines
# HR id 106: 38 IMU lines
# HR id 107: 30 IMU lines
# HR id 108: 35 IMU lines
# HR id 109: 20 IMU lines
# HR id 110: 20 IMU lines
# HR id 111: 18 IMU lines
# HR id 112: 13 IMU lines
# HR id 113: 21 IMU lines
# HR id 114: 19 IMU lines
# HR id 115: 18 IMU lines
# HR id 116: 19 IMU lines
# HR id 117: 33 IMU lines
# HR id 118: 34 IMU lines
# HR id 119: 69 IMU lines
# HR id 120: 34 IMU lines
# HR id 121: 74 IMU lines
# HR id 122: 33 IMU lines
# HR id 123: 56 IMU lines
# HR id 124: 50 IMU lines
# HR id 125: 70 IMU lines
# HR id 126: 17 IMU lines
# HR id 127: 35 IMU lines
# HR id 128: 20 IMU lines
# HR id 129: 21 IMU lines
# HR id 130: 50 IMU lines
# HR id 131: 72 IMU lines
# HR id 132: 36 IMU lines
# HR id 133: 71 IMU lines
# HR id 134: 15 IMU lines
# HR id 135: 19 IMU lines
# HR id 136: 17 IMU lines
# HR id 137: 20 IMU lines
# HR id 138: 20 IMU lines
# HR id 139: 34 IMU lines
# HR id 140: 35 IMU lines
# HR id 141: 19 IMU lines
# HR id 142: 37 IMU lines
# HR id 143: 34 IMU lines
# HR id 144: 16 IMU lines
# HR id 145: 14 IMU lines
# HR id 146: 77 IMU lines
# HR id 147: 18 IMU lines
# HR id 148: 16 IMU lines
# HR id 149: 36 IMU lines
# HR id 150: 32 IMU lines
# HR id 151: 78 IMU lines
# HR id 152: 14 IMU lines
# HR id 153: 16 IMU lines
# HR id 154: 39 IMU lines
# HR id 155: 37 IMU lines
# HR id 156: 34 IMU lines
# HR id 157: 72 IMU lines
# HR id 158: 31 IMU lines
# HR id 159: 71 IMU lines
# HR id 160: 20 IMU lines
# HR id 161: 17 IMU lines
# HR id 162: 57 IMU lines
# HR id 163: 31 IMU lines
# HR id 164: 55 IMU lines
# HR id 165: 37 IMU lines
# HR id 166: 72 IMU lines
# HR id 167: 33 IMU lines
# HR id 168: 74 IMU lines
# HR id 169: 33 IMU lines
# HR id 170: 38 IMU lines
# HR id 171: 35 IMU lines
# HR id 172: 16 IMU lines
# HR id 173: 18 IMU lines
# HR id 174: 15 IMU lines
# HR id 175: 21 IMU lines
# HR id 176: 18 IMU lines
# HR id 177: 33 IMU lines
# HR id 178: 20 IMU lines
# HR id 179: 37 IMU lines
# HR id 180: 32 IMU lines
# HR id 181: 38 IMU lines
# HR id 182: 38 IMU lines
# HR id 183: 33 IMU lines
# HR id 184: 18 IMU lines
# HR id 185: 13 IMU lines
# HR id 186: 56 IMU lines
# HR id 187: 17 IMU lines
# HR id 188: 41 IMU lines
# HR id 189: 33 IMU lines
# HR id 190: 16 IMU lines
# HR id 191: 16 IMU lines
# HR id 192: 73 IMU lines
# HR id 193: 18 IMU lines
# HR id 194: 15 IMU lines
# HR id 195: 41 IMU lines
# HR id 196: 15 IMU lines
# HR id 197: 18 IMU lines
# HR id 198: 73 IMU lines
# HR id 199: 15 IMU lines
# HR id 200: 32 IMU lines
# HR id 201: 19 IMU lines
# HR id 202: 18 IMU lines
# HR id 203: 69 IMU lines
# HR id 204: 15 IMU lines
# HR id 205: 21 IMU lines
# HR id 206: 72 IMU lines
# HR id 207: 36 IMU lines
# HR id 208: 34 IMU lines
# HR id 209: 19 IMU lines
# HR id 210: 18 IMU lines
# HR id 211: 20 IMU lines
# HR id 212: 50 IMU lines
# HR id 213: 18 IMU lines
# HR id 214: 49 IMU lines
# HR id 215: 24 IMU lines
# HR id 216: 15 IMU lines
# HR id 217: 41 IMU lines
# HR id 218: 28 IMU lines
# HR id 219: 42 IMU lines
# HR id 220: 38 IMU lines
# HR id 221: 14 IMU lines
# HR id 222: 17 IMU lines
# HR id 223: 20 IMU lines
# HR id 224: 54 IMU lines
# HR id 225: 35 IMU lines
# HR id 226: 68 IMU lines
# HR id 227: 34 IMU lines
# HR id 228: 24 IMU lines
# HR id 229: 31 IMU lines
# HR id 230: 17 IMU lines
# HR id 231: 23 IMU lines
# HR id 232: 16 IMU lines
# HR id 233: 33 IMU lines
# HR id 234: 20 IMU lines
# HR id 235: 16 IMU lines
# HR id 236: 72 IMU lines
# HR id 237: 35 IMU lines
# HR id 238: 19 IMU lines
# HR id 239: 16 IMU lines
# HR id 240: 21 IMU lines
# HR id 241: 17 IMU lines
# HR id 242: 37 IMU lines
# HR id 243: 35 IMU lines
# HR id 244: 30 IMU lines
# HR id 245: 40 IMU lines
# HR id 246: 15 IMU lines
# HR id 247: 37 IMU lines
# HR id 248: 19 IMU lines
# HR id 249: 35 IMU lines
# HR id 250: 37 IMU lines
# HR id 251: 35 IMU lines
# HR id 252: 34 IMU lines
# HR id 253: 18 IMU lines
# HR id 254: 16 IMU lines
# HR id 255: 19 IMU lines
# HR id 256: 20 IMU lines
# HR id 257: 50 IMU lines
# HR id 258: 18 IMU lines
# HR id 259: 36 IMU lines
# HR id 260: 74 IMU lines
# HR id 261: 32 IMU lines
# HR id 262: 21 IMU lines
# HR id 263: 35 IMU lines
# HR id 264: 21 IMU lines
# HR id 265: 35 IMU lines
# HR id 266: 31 IMU lines
# HR id 267: 37 IMU lines
# HR id 268: 21 IMU lines
# HR id 269: 18 IMU lines
# HR id 270: 37 IMU lines
# HR id 271: 13 IMU lines
# HR id 272: 17 IMU lines
# HR id 273: 22 IMU lines
# HR id 274: 15 IMU lines
# HR id 275: 37 IMU lines
# HR id 276: 37 IMU lines
# HR id 277: 13 IMU lines
# HR id 278: 19 IMU lines
# HR id 279: 34 IMU lines
# HR id 280: 24 IMU lines
# HR id 281: 51 IMU lines
# HR id 282: 17 IMU lines
# HR id 283: 50 IMU lines
# HR id 284: 38 IMU lines
# HR id 285: 16 IMU lines
# HR id 286: 35 IMU lines
# HR id 287: 18 IMU lines
# HR id 288: 18 IMU lines
# HR id 289: 16 IMU lines
# HR id 290: 39 IMU lines
# HR id 291: 34 IMU lines
# HR id 292: 19 IMU lines
# HR id 293: 16 IMU lines
# HR id 294: 19 IMU lines
# HR id 295: 16 IMU lines
# HR id 296: 38 IMU lines
# HR id 297: 20 IMU lines
# HR id 298: 13 IMU lines
# HR id 299: 21 IMU lines
# HR id 300: 17 IMU lines
# HR id 301: 18 IMU lines
# HR id 302: 14 IMU lines
# HR id 303: 19 IMU lines
# HR id 304: 17 IMU lines
# HR id 305: 19 IMU lines
# HR id 306: 16 IMU lines
# HR id 307: 21 IMU lines
# HR id 308: 14 IMU lines
# HR id 309: 19 IMU lines
# HR id 310: 18 IMU lines
# HR id 311: 37 IMU lines
# HR id 312: 18 IMU lines
# HR id 313: 17 IMU lines
# HR id 314: 17 IMU lines
# HR id 315: 16 IMU lines
# HR id 316: 18 IMU lines
# HR id 317: 19 IMU lines
# HR id 318: 17 IMU lines
# HR id 319: 16 IMU lines
# HR id 320: 18 IMU lines
# HR id 321: 20 IMU lines
# HR id 322: 18 IMU lines
# HR id 323: 15 IMU lines
# HR id 324: 16 IMU lines
# HR id 325: 20 IMU lines
# HR id 326: 33 IMU lines
# HR id 327: 20 IMU lines
# HR id 328: 16 IMU lines
# HR id 329: 36 IMU lines
# HR id 330: 16 IMU lines
# HR id 331: 20 IMU lines
# HR id 332: 17 IMU lines
# HR id 333: 20 IMU lines
# HR id 334: 16 IMU lines
# HR id 335: 16 IMU lines
# HR id 336: 19 IMU lines
# HR id 337: 17 IMU lines
# HR id 338: 16 IMU lines
# HR id 339: 18 IMU lines
# HR id 340: 18 IMU lines
# HR id 341: 19 IMU lines
# HR id 342: 17 IMU lines
# HR id 343: 17 IMU lines
# HR id 344: 36 IMU lines
# HR id 345: 18 IMU lines
# HR id 346: 16 IMU lines
# HR id 347: 17 IMU lines
# HR id 348: 22 IMU lines
# HR id 349: 15 IMU lines
# HR id 350: 17 IMU lines
# HR id 351: 20 IMU lines
# HR id 352: 18 IMU lines
# HR id 353: 16 IMU lines
# HR id 354: 17 IMU lines
# HR id 355: 18 IMU lines
# HR id 356: 35 IMU lines
# HR id 357: 17 IMU lines
# HR id 358: 18 IMU lines
# HR id 359: 19 IMU lines
# HR id 360: 19 IMU lines
# HR id 361: 15 IMU lines
# HR id 362: 19 IMU lines
# HR id 363: 19 IMU lines
# HR id 364: 15 IMU lines
# HR id 365: 18 IMU lines
# HR id 366: 19 IMU lines
# HR id 367: 17 IMU lines
# HR id 368: 18 IMU lines
# HR id 369: 16 IMU lines
# HR id 370: 22 IMU lines
# HR id 371: 18 IMU lines
# HR id 372: 18 IMU lines
# HR id 373: 19 IMU lines
# HR id 374: 36 IMU lines
# HR id 375: 17 IMU lines
# HR id 376: 19 IMU lines
# HR id 377: 17 IMU lines
# HR id 378: 18 IMU lines
# HR id 379: 19 IMU lines
# HR id 380: 19 IMU lines
# HR id 381: 13 IMU lines
# HR id 382: 23 IMU lines
# HR id 383: 34 IMU lines
# HR id 384: 19 IMU lines
# HR id 385: 19 IMU lines
# HR id 386: 16 IMU lines
# HR id 387: 19 IMU lines
# HR id 388: 18 IMU lines
# HR id 389: 16 IMU lines
# HR id 390: 16 IMU lines
# HR id 391: 20 IMU lines
# HR id 392: 18 IMU lines
# HR id 393: 18 IMU lines
# HR id 394: 36 IMU lines
# HR id 395: 17 IMU lines
# HR id 396: 18 IMU lines
# HR id 397: 18 IMU lines
# HR id 398: 19 IMU lines
# HR id 399: 14 IMU lines
# HR id 400: 22 IMU lines
# HR id 401: 16 IMU lines
# HR id 402: 18 IMU lines
# HR id 403: 18 IMU lines
# HR id 404: 17 IMU lines
# HR id 405: 17 IMU lines
# HR id 406: 18 IMU lines
# HR id 407: 18 IMU lines
# HR id 408: 19 IMU lines
# HR id 409: 15 IMU lines
# HR id 410: 22 IMU lines
# HR id 411: 15 IMU lines
# HR id 412: 18 IMU lines
# HR id 413: 20 IMU lines
# HR id 414: 17 IMU lines
# HR id 415: 16 IMU lines
# HR id 416: 20 IMU lines
# HR id 417: 18 IMU lines
# HR id 418: 17 IMU lines
# HR id 419: 14 IMU lines
# HR id 420: 23 IMU lines
# HR id 421: 16 IMU lines
# HR id 422: 18 IMU lines
# HR id 423: 35 IMU lines
# HR id 424: 18 IMU lines
# HR id 425: 18 IMU lines
# HR id 426: 21 IMU lines
# HR id 427: 15 IMU lines
# HR id 428: 13 IMU lines
# HR id 429: 23 IMU lines
# HR id 430: 18 IMU lines
# HR id 431: 19 IMU lines
# HR id 432: 36 IMU lines
# HR id 433: 16 IMU lines
# HR id 434: 18 IMU lines
# HR id 435: 19 IMU lines
# HR id 436: 17 IMU lines
# HR id 437: 14 IMU lines
# HR id 438: 21 IMU lines
# HR id 439: 18 IMU lines
# HR id 440: 18 IMU lines
# HR id 441: 17 IMU lines
# HR id 442: 17 IMU lines
# HR id 443: 18 IMU lines
# HR id 444: 17 IMU lines
# HR id 445: 20 IMU lines
# HR id 446: 16 IMU lines
# HR id 447: 12 IMU lines
# HR id 448: 24 IMU lines
# HR id 449: 24 IMU lines
# HR id 450: 12 IMU lines
# HR id 451: 14 IMU lines
# HR id 452: 21 IMU lines
# HR id 453: 16 IMU lines
# HR id 454: 18 IMU lines
# HR id 455: 37 IMU lines
# HR id 456: 17 IMU lines
# HR id 457: 20 IMU lines
# HR id 458: 17 IMU lines
# HR id 459: 26 IMU lines
# HR id 460: 26 IMU lines
# HR id 461: 21 IMU lines
# HR id 462: 15 IMU lines
# HR id 463: 15 IMU lines
# HR id 464: 21 IMU lines
# HR id 465: 17 IMU lines
# HR id 466: 18 IMU lines
# HR id 467: 34 IMU lines
# HR id 468: 19 IMU lines
# HR id 469: 16 IMU lines
# HR id 470: 21 IMU lines
# HR id 471: 15 IMU lines
# HR id 472: 14 IMU lines
# HR id 473: 23 IMU lines
# HR id 474: 34 IMU lines
# HR id 475: 18 IMU lines
# HR id 476: 19 IMU lines
# HR id 477: 16 IMU lines
# HR id 478: 16 IMU lines
# HR id 479: 21 IMU lines
# HR id 480: 16 IMU lines
# HR id 481: 18 IMU lines
# HR id 482: 17 IMU lines
# HR id 483: 22 IMU lines
# HR id 484: 15 IMU lines
# HR id 485: 14 IMU lines
# HR id 486: 21 IMU lines
# HR id 487: 17 IMU lines
# HR id 488: 18 IMU lines
# HR id 489: 42 IMU lines
# HR id 490: 12 IMU lines
# HR id 491: 16 IMU lines
# HR id 492: 21 IMU lines
# HR id 493: 16 IMU lines
# HR id 494: 14 IMU lines
# HR id 495: 23 IMU lines
# HR id 496: 34 IMU lines
# HR id 497: 17 IMU lines
# HR id 498: 20 IMU lines
# HR id 499: 17 IMU lines
# HR id 500: 19 IMU lines
# HR id 501: 18 IMU lines
# HR id 502: 17 IMU lines
# HR id 503: 13 IMU lines
# HR id 504: 23 IMU lines
# HR id 505: 25 IMU lines
# HR id 506: 13 IMU lines
# HR id 507: 13 IMU lines
# HR id 508: 21 IMU lines
# HR id 509: 17 IMU lines
# HR id 510: 18 IMU lines
# HR id 511: 19 IMU lines
# HR id 512: 16 IMU lines
# HR id 513: 13 IMU lines
# HR id 514: 22 IMU lines
# HR id 515: 25 IMU lines
# HR id 516: 13 IMU lines
# HR id 517: 13 IMU lines
# HR id 518: 20 IMU lines
# HR id 519: 18 IMU lines
# HR id 520: 17 IMU lines
# HR id 521: 20 IMU lines
# HR id 522: 15 IMU lines
# HR id 523: 14 IMU lines
# HR id 524: 22 IMU lines
# HR id 525: 37 IMU lines
# HR id 526: 16 IMU lines
# HR id 527: 17 IMU lines
# HR id 528: 37 IMU lines
# HR id 529: 19 IMU lines
# HR id 530: 17 IMU lines
# HR id 531: 13 IMU lines
# HR id 532: 23 IMU lines
# HR id 533: 16 IMU lines
# HR id 534: 17 IMU lines
# HR id 535: 18 IMU lines
# HR id 536: 19 IMU lines
# HR id 537: 17 IMU lines
# HR id 538: 15 IMU lines
# HR id 539: 22 IMU lines
# HR id 540: 16 IMU lines
# HR id 541: 15 IMU lines
# HR id 542: 21 IMU lines
# HR id 543: 17 IMU lines
# HR id 544: 18 IMU lines
# HR id 545: 17 IMU lines
# HR id 546: 18 IMU lines
# HR id 547: 18 IMU lines
# HR id 548: 16 IMU lines
# HR id 549: 23 IMU lines
# HR id 550: 14 IMU lines
# HR id 551: 13 IMU lines
# HR id 552: 25 IMU lines
# HR id 553: 24 IMU lines
# HR id 554: 26 IMU lines
# HR id 555: 19 IMU lines
# HR id 556: 18 IMU lines
# HR id 557: 18 IMU lines
# HR id 558: 19 IMU lines
# HR id 559: 17 IMU lines
# HR id 560: 12 IMU lines
# HR id 561: 24 IMU lines
# HR id 562: 33 IMU lines
# HR id 563: 35 IMU lines
# HR id 564: 18 IMU lines
# HR id 565: 17 IMU lines
# HR id 566: 22 IMU lines
# HR id 567: 14 IMU lines
# HR id 568: 14 IMU lines
# HR id 569: 23 IMU lines
# HR id 570: 16 IMU lines
# HR id 571: 16 IMU lines
# HR id 572: 20 IMU lines
# HR id 573: 17 IMU lines
# HR id 574: 13 IMU lines
# HR id 575: 47 IMU lines
# HR id 576: 13 IMU lines
# HR id 577: 14 IMU lines
# HR id 578: 22 IMU lines
# HR id 579: 15 IMU lines
# HR id 580: 15 IMU lines
# HR id 581: 22 IMU lines
# HR id 582: 16 IMU lines
# HR id 583: 18 IMU lines
# HR id 584: 17 IMU lines
# HR id 585: 26 IMU lines
# HR id 586: 25 IMU lines
# HR id 587: 23 IMU lines
# HR id 588: 17 IMU lines
# HR id 589: 17 IMU lines
# HR id 590: 18 IMU lines
# HR id 591: 19 IMU lines
# HR id 592: 17 IMU lines
# HR id 593: 18 IMU lines
# HR id 594: 21 IMU lines
# HR id 595: 16 IMU lines
# HR id 596: 13 IMU lines
# HR id 597: 23 IMU lines
# HR id 598: 17 IMU lines
# HR id 599: 18 IMU lines
# HR id 600: 17 IMU lines
# HR id 601: 23 IMU lines
# HR id 602: 13 IMU lines
# HR id 603: 19 IMU lines
# HR id 604: 19 IMU lines
# HR id 605: 15 IMU lines
# HR id 606: 13 IMU lines
# HR id 607: 23 IMU lines
# HR id 608: 25 IMU lines
# HR id 609: 13 IMU lines
# HR id 610: 13 IMU lines
# HR id 611: 22 IMU lines
# HR id 612: 34 IMU lines
# HR id 613: 36 IMU lines
# HR id 614: 17 IMU lines
# HR id 615: 17 IMU lines
# HR id 616: 21 IMU lines
# HR id 617: 16 IMU lines
# HR id 618: 12 IMU lines
# HR id 619: 24 IMU lines
# HR id 620: 23 IMU lines
# HR id 621: 13 IMU lines
# HR id 622: 13 IMU lines
# HR id 623: 21 IMU lines
# HR id 624: 36 IMU lines
# HR id 625: 16 IMU lines
# HR id 626: 23 IMU lines
# HR id 627: 33 IMU lines
# HR id 628: 18 IMU lines
# HR id 629: 18 IMU lines
# HR id 630: 34 IMU lines
# HR id 631: 21 IMU lines
# HR id 632: 15 IMU lines
# HR id 633: 13 IMU lines
# HR id 634: 22 IMU lines
# HR id 635: 25 IMU lines
# HR id 636: 13 IMU lines
# HR id 637: 13 IMU lines
# HR id 638: 24 IMU lines
# HR id 639: 25 IMU lines
# HR id 640: 23 IMU lines
# HR id 641: 34 IMU lines
# HR id 642: 18 IMU lines
# HR id 643: 26 IMU lines
# HR id 644: 28 IMU lines
# HR id 645: 23 IMU lines
# HR id 646: 15 IMU lines
# HR id 647: 13 IMU lines
# HR id 648: 25 IMU lines
# HR id 649: 35 IMU lines
# HR id 650: 36 IMU lines
# HR id 651: 36 IMU lines
# HR id 652: 25 IMU lines
# HR id 653: 13 IMU lines
# HR id 654: 13 IMU lines
# HR id 655: 20 IMU lines
# HR id 656: 34 IMU lines
# HR id 657: 21 IMU lines
# HR id 658: 16 IMU lines
# HR id 659: 13 IMU lines
# HR id 660: 24 IMU lines
# HR id 661: 27 IMU lines
# HR id 662: 25 IMU lines
# HR id 663: 26 IMU lines
# HR id 664: 28 IMU lines
# HR id 665: 23 IMU lines
# HR id 666: 13 IMU lines
# HR id 667: 14 IMU lines
# HR id 668: 23 IMU lines
# HR id 669: 34 IMU lines
# HR id 670: 20 IMU lines
# HR id 671: 16 IMU lines
# HR id 672: 13 IMU lines
# HR id 673: 22 IMU lines
# HR id 674: 35 IMU lines
# HR id 675: 17 IMU lines
# HR id 676: 18 IMU lines
# HR id 677: 18 IMU lines
# HR id 678: 17 IMU lines
# HR id 679: 24 IMU lines
# HR id 680: 13 IMU lines
# HR id 681: 13 IMU lines
# HR id 682: 25 IMU lines
# HR id 683: 25 IMU lines
# HR id 684: 27 IMU lines
# HR id 685: 25 IMU lines
# HR id 686: 26 IMU lines
# HR id 687: 25 IMU lines
# HR id 688: 28 IMU lines
# HR id 689: 26 IMU lines
# HR id 690: 27 IMU lines
# HR id 691: 27 IMU lines
# HR id 692: 27 IMU lines
# HR id 693: 26 IMU lines
# HR id 694: 27 IMU lines
# HR id 695: 27 IMU lines
# HR id 696: 28 IMU lines
# HR id 697: 27 IMU lines
# HR id 698: 26 IMU lines
# HR id 699: 27 IMU lines
# HR id 700: 27 IMU lines
# HR id 701: 27 IMU lines
# HR id 702: 27 IMU lines
# HR id 703: 28 IMU lines
# HR id 704: 27 IMU lines
# HR id 705: 27 IMU lines
# HR id 706: 26 IMU lines
# HR id 707: 28 IMU lines
# HR id 708: 27 IMU lines
# HR id 709: 27 IMU lines
# HR id 710: 27 IMU lines
# HR id 711: 28 IMU lines
# HR id 712: 27 IMU lines
# HR id 713: 28 IMU lines
# HR id 714: 28 IMU lines
# HR id 715: 27 IMU lines
# HR id 716: 28 IMU lines
# HR id 717: 27 IMU lines
# HR id 718: 27 IMU lines
# HR id 719: 29 IMU lines
# HR id 720: 27 IMU lines
# HR id 721: 28 IMU lines
# HR id 722: 29 IMU lines
# HR id 723: 27 IMU lines
# HR id 724: 28 IMU lines
# HR id 725: 29 IMU lines
# HR id 726: 30 IMU lines
# HR id 727: 28 IMU lines
# HR id 728: 28 IMU lines
# HR id 729: 29 IMU lines
# HR id 730: 29 IMU lines
# HR id 731: 29 IMU lines
# HR id 732: 28 IMU lines
# HR id 733: 28 IMU lines
# HR id 734: 28 IMU lines
# HR id 735: 28 IMU lines
# HR id 736: 28 IMU lines
# HR id 737: 28 IMU lines
# HR id 738: 31 IMU lines
# HR id 739: 28 IMU lines
# HR id 740: 30 IMU lines
# HR id 741: 29 IMU lines
# HR id 742: 29 IMU lines
# HR id 743: 28 IMU lines
# HR id 744: 27 IMU lines
# HR id 745: 28 IMU lines
# HR id 746: 28 IMU lines
# HR id 747: 28 IMU lines
# HR id 748: 27 IMU lines
# HR id 749: 29 IMU lines
# HR id 750: 29 IMU lines
# HR id 751: 29 IMU lines
# HR id 752: 28 IMU lines
# HR id 753: 29 IMU lines
# HR id 754: 28 IMU lines
# HR id 755: 32 IMU lines
# HR id 756: 29 IMU lines
# HR id 757: 30 IMU lines
# HR id 758: 30 IMU lines
# HR id 759: 28 IMU lines
# HR id 760: 30 IMU lines
# HR id 761: 30 IMU lines
# HR id 762: 30 IMU lines
# HR id 763: 30 IMU lines
# HR id 764: 30 IMU lines
# HR id 765: 29 IMU lines
# HR id 766: 31 IMU lines
# HR id 767: 30 IMU lines
# HR id 768: 30 IMU lines
# HR id 769: 30 IMU lines
# HR id 770: 29 IMU lines
# HR id 771: 29 IMU lines
# HR id 772: 31 IMU lines
# HR id 773: 30 IMU lines
# HR id 774: 29 IMU lines
# HR id 775: 30 IMU lines
# HR id 776: 30 IMU lines
# HR id 777: 30 IMU lines
# HR id 778: 30 IMU lines
# HR id 779: 29 IMU lines
# HR id 780: 29 IMU lines
# HR id 781: 30 IMU lines
# HR id 782: 28 IMU lines
# HR id 783: 30 IMU lines
# HR id 784: 29 IMU lines
# HR id 785: 28 IMU lines
# HR id 786: 31 IMU lines
# HR id 787: 28 IMU lines
# HR id 788: 30 IMU lines
# HR id 789: 29 IMU lines
# HR id 790: 31 IMU lines
# HR id 791: 30 IMU lines
# HR id 792: 32 IMU lines
# HR id 793: 29 IMU lines
# HR id 794: 30 IMU lines
# HR id 795: 30 IMU lines
# HR id 796: 31 IMU lines
# HR id 797: 29 IMU lines
# HR id 798: 30 IMU lines
# HR id 799: 29 IMU lines
# HR id 800: 29 IMU lines
# HR id 801: 31 IMU lines
# HR id 802: 30 IMU lines
# HR id 803: 29 IMU lines
# HR id 804: 30 IMU lines
# HR id 805: 31 IMU lines
# HR id 806: 31 IMU lines
# HR id 807: 32 IMU lines
# HR id 808: 31 IMU lines
# HR id 809: 31 IMU lines
# HR id 810: 30 IMU lines
# HR id 811: 32 IMU lines
# HR id 812: 29 IMU lines
# HR id 813: 31 IMU lines
# HR id 814: 30 IMU lines
# HR id 815: 31 IMU lines
# HR id 816: 29 IMU lines
# HR id 817: 31 IMU lines
# HR id 818: 30 IMU lines
# HR id 819: 30 IMU lines
# HR id 820: 30 IMU lines
# HR id 821: 30 IMU lines
# HR id 822: 31 IMU lines
# HR id 823: 30 IMU lines
# HR id 824: 30 IMU lines
# HR id 825: 30 IMU lines
# HR id 826: 30 IMU lines
# HR id 827: 29 IMU lines
# HR id 828: 30 IMU lines
# HR id 829: 30 IMU lines
# HR id 830: 16 IMU lines
# HR id 831: 13 IMU lines
# HR id 832: 26 IMU lines
# HR id 833: 34 IMU lines
# HR id 834: 27 IMU lines
# HR id 835: 13 IMU lines
# HR id 836: 17 IMU lines
# HR id 837: 19 IMU lines
# HR id 838: 13 IMU lines
# HR id 839: 26 IMU lines
# HR id 840: 33 IMU lines
# HR id 841: 29 IMU lines
# HR id 842: 29 IMU lines
# HR id 843: 15 IMU lines
# HR id 844: 15 IMU lines
# HR id 845: 20 IMU lines
# HR id 846: 13 IMU lines
# HR id 847: 24 IMU lines
# HR id 848: 33 IMU lines
# HR id 849: 27 IMU lines
# HR id 850: 12 IMU lines
# HR id 851: 16 IMU lines
# HR id 852: 18 IMU lines
# HR id 853: 13 IMU lines
# HR id 854: 24 IMU lines
# HR id 855: 32 IMU lines
# HR id 856: 26 IMU lines
# HR id 857: 13 IMU lines
# HR id 858: 16 IMU lines
# HR id 859: 18 IMU lines
# HR id 860: 37 IMU lines
# HR id 861: 30 IMU lines
# HR id 862: 25 IMU lines
# HR id 863: 14 IMU lines
# HR id 864: 14 IMU lines
# HR id 865: 26 IMU lines
# HR id 866: 31 IMU lines
# HR id 867: 26 IMU lines
# HR id 868: 13 IMU lines
# HR id 869: 15 IMU lines
# HR id 870: 19 IMU lines
# HR id 871: 35 IMU lines
# HR id 872: 36 IMU lines
# HR id 873: 19 IMU lines
# HR id 874: 17 IMU lines
# HR id 875: 13 IMU lines
# HR id 876: 24 IMU lines
# HR id 877: 35 IMU lines
# HR id 878: 21 IMU lines
# HR id 879: 15 IMU lines
# HR id 880: 13 IMU lines
# HR id 881: 24 IMU lines
# HR id 882: 32 IMU lines
# HR id 883: 25 IMU lines
# HR id 884: 13 IMU lines
# HR id 885: 14 IMU lines
# HR id 886: 20 IMU lines
# HR id 887: 36 IMU lines
# HR id 888: 25 IMU lines
# HR id 889: 27 IMU lines
# HR id 890: 27 IMU lines
# HR id 891: 28 IMU lines
# HR id 892: 37 IMU lines
# HR id 893: 18 IMU lines
# HR id 894: 18 IMU lines
# HR id 895: 13 IMU lines
# HR id 896: 23 IMU lines
# HR id 897: 35 IMU lines
# HR id 898: 21 IMU lines
# HR id 899: 14 IMU lines
# HR id 900: 14 IMU lines
# HR id 901: 24 IMU lines
# HR id 902: 33 IMU lines
# HR id 903: 26 IMU lines
# HR id 904: 12 IMU lines
# HR id 905: 16 IMU lines
# HR id 906: 19 IMU lines
# HR id 907: 36 IMU lines
# HR id 908: 35 IMU lines
# HR id 909: 22 IMU lines
# HR id 910: 14 IMU lines
# HR id 911: 13 IMU lines
# HR id 912: 24 IMU lines
# HR id 913: 33 IMU lines
# HR id 914: 25 IMU lines
# HR id 915: 13 IMU lines
# HR id 916: 16 IMU lines
# HR id 917: 18 IMU lines
# HR id 918: 35 IMU lines
# HR id 919: 35 IMU lines
# HR id 920: 20 IMU lines
# HR id 921: 15 IMU lines
# HR id 922: 14 IMU lines
# HR id 923: 25 IMU lines
# HR id 924: 31 IMU lines
# HR id 925: 26 IMU lines
# HR id 926: 13 IMU lines
# HR id 927: 15 IMU lines
# HR id 928: 18 IMU lines
# HR id 929: 36 IMU lines
# HR id 930: 35 IMU lines
# HR id 931: 20 IMU lines
# HR id 932: 15 IMU lines
# HR id 933: 13 IMU lines
# HR id 934: 24 IMU lines
# HR id 935: 33 IMU lines
# HR id 936: 26 IMU lines
# HR id 937: 12 IMU lines
# HR id 938: 15 IMU lines
# HR id 939: 19 IMU lines
# HR id 940: 35 IMU lines
# HR id 941: 36 IMU lines
# HR id 942: 18 IMU lines
# HR id 943: 19 IMU lines
# HR id 944: 35 IMU lines
# HR id 945: 35 IMU lines
# HR id 946: 18 IMU lines
# HR id 947: 18 IMU lines
# HR id 948: 17 IMU lines
# HR id 949: 43 IMU lines
# HR id 950: 28 IMU lines
# HR id 951: 26 IMU lines
# HR id 952: 27 IMU lines
# HR id 953: 26 IMU lines
# HR id 954: 13 IMU lines
# HR id 955: 14 IMU lines
# HR id 956: 26 IMU lines
# HR id 957: 27 IMU lines
# HR id 958: 26 IMU lines
# HR id 959: 27 IMU lines
# HR id 960: 28 IMU lines
# HR id 961: 26 IMU lines
# HR id 962: 26 IMU lines
# HR id 963: 27 IMU lines
# HR id 964: 26 IMU lines
# HR id 965: 28 IMU lines
# HR id 966: 27 IMU lines
# HR id 967: 26 IMU lines
# HR id 968: 27 IMU lines
# HR id 969: 28 IMU lines
# HR id 970: 26 IMU lines
# HR id 971: 28 IMU lines
# HR id 972: 27 IMU lines
# HR id 973: 27 IMU lines
# HR id 974: 27 IMU lines
# HR id 975: 28 IMU lines
# HR id 976: 28 IMU lines
# HR id 977: 26 IMU lines
# HR id 978: 28 IMU lines
# HR id 979: 27 IMU lines
# HR id 980: 28 IMU lines
# HR id 981: 27 IMU lines
# HR id 982: 28 IMU lines
# HR id 983: 28 IMU lines
# HR id 984: 29 IMU lines
# HR id 985: 27 IMU lines
# HR id 986: 28 IMU lines
# HR id 987: 28 IMU lines
# HR id 988: 28 IMU lines
# HR id 989: 29 IMU lines
# HR id 990: 27 IMU lines
# HR id 991: 31 IMU lines
# HR id 992: 30 IMU lines
# HR id 993: 28 IMU lines
# HR id 994: 30 IMU lines
# HR id 995: 29 IMU lines
# HR id 996: 28 IMU lines
# HR id 997: 30 IMU lines
# HR id 998: 28 IMU lines
# HR id 999: 28 IMU lines
# HR id 1000: 30 IMU lines
# HR id 1001: 28 IMU lines
# HR id 1002: 28 IMU lines
# HR id 1003: 29 IMU lines
# HR id 1004: 29 IMU lines
# HR id 1005: 29 IMU lines
# HR id 1006: 28 IMU lines
# HR id 1007: 29 IMU lines
# HR id 1008: 29 IMU lines
# HR id 1009: 29 IMU lines
# HR id 1010: 30 IMU lines
# HR id 1011: 29 IMU lines
# HR id 1012: 29 IMU lines
# HR id 1013: 28 IMU lines
# HR id 1014: 30 IMU lines
# HR id 1015: 30 IMU lines
# HR id 1016: 29 IMU lines
# HR id 1017: 29 IMU lines
# HR id 1018: 30 IMU lines
# HR id 1019: 30 IMU lines
# HR id 1020: 29 IMU lines
# HR id 1021: 30 IMU lines
# HR id 1022: 30 IMU lines
# HR id 1023: 29 IMU lines
# HR id 1024: 30 IMU lines
# HR id 1025: 29 IMU lines
# HR id 1026: 29 IMU lines
# HR id 1027: 31 IMU lines
# HR id 1028: 31 IMU lines
# HR id 1029: 32 IMU lines
# HR id 1030: 31 IMU lines
# HR id 1031: 30 IMU lines
# HR id 1032: 30 IMU lines
# HR id 1033: 30 IMU lines
# HR id 1034: 30 IMU lines
# HR id 1035: 30 IMU lines
# HR id 1036: 31 IMU lines
# HR id 1037: 30 IMU lines
# HR id 1038: 30 IMU lines
# HR id 1039: 30 IMU lines
# HR id 1040: 29 IMU lines
# HR id 1041: 32 IMU lines
# HR id 1042: 29 IMU lines
# HR id 1043: 31 IMU lines
# HR id 1044: 30 IMU lines
# HR id 1045: 31 IMU lines
# HR id 1046: 30 IMU lines
# HR id 1047: 31 IMU lines
# HR id 1048: 31 IMU lines
# HR id 1049: 31 IMU lines
# HR id 1050: 31 IMU lines
# HR id 1051: 30 IMU lines
# HR id 1052: 30 IMU lines
# HR id 1053: 30 IMU lines
# HR id 1054: 32 IMU lines
# HR id 1055: 30 IMU lines
# HR id 1056: 29 IMU lines
# HR id 1057: 31 IMU lines
# HR id 1058: 33 IMU lines
# HR id 1059: 34 IMU lines
# HR id 1060: 34 IMU lines
# HR id 1061: 31 IMU lines
# HR id 1062: 31 IMU lines
# HR id 1063: 32 IMU lines
# HR id 1064: 32 IMU lines
# HR id 1065: 30 IMU lines
# HR id 1066: 31 IMU lines
# HR id 1067: 30 IMU lines
# HR id 1068: 30 IMU lines
# HR id 1069: 31 IMU lines
# HR id 1070: 31 IMU lines
# HR id 1071: 29 IMU lines
# HR id 1072: 32 IMU lines
# HR id 1073: 30 IMU lines
# HR id 1074: 30 IMU lines
# HR id 1075: 29 IMU lines
# HR id 1076: 33 IMU lines
# HR id 1077: 33 IMU lines
# HR id 1078: 32 IMU lines
# HR id 1079: 31 IMU lines
# HR id 1080: 31 IMU lines
# HR id 1081: 32 IMU lines
# HR id 1082: 31 IMU lines
# HR id 1083: 34 IMU lines
# HR id 1084: 35 IMU lines
# HR id 1085: 34 IMU lines
# HR id 1086: 32 IMU lines
# HR id 1087: 32 IMU lines
# HR id 1088: 32 IMU lines
# HR id 1089: 32 IMU lines
# HR id 1090: 32 IMU lines
# HR id 1091: 32 IMU lines
# HR id 1092: 32 IMU lines
# HR id 1093: 31 IMU lines
# HR id 1094: 32 IMU lines
# HR id 1095: 31 IMU lines
# HR id 1096: 33 IMU lines
# HR id 1097: 32 IMU lines
# HR id 1098: 32 IMU lines
# HR id 1099: 31 IMU lines
# HR id 1100: 31 IMU lines
# HR id 1101: 30 IMU lines
# HR id 1102: 30 IMU lines
# HR id 1103: 31 IMU lines
# HR id 1104: 29 IMU lines
# HR id 1105: 32 IMU lines
# HR id 1106: 30 IMU lines
# HR id 1107: 31 IMU lines
# HR id 1108: 31 IMU lines
# HR id 1109: 30 IMU lines
# HR id 1110: 34 IMU lines
# HR id 1111: 32 IMU lines
# HR id 1112: 33 IMU lines
# HR id 1113: 31 IMU lines
# HR id 1114: 32 IMU lines
# HR id 1115: 32 IMU lines
# HR id 1116: 31 IMU lines
# HR id 1117: 31 IMU lines
# HR id 1118: 31 IMU lines
# HR id 1119: 19 IMU lines
# HR id 1120: 13 IMU lines
# HR id 1121: 25 IMU lines
# HR id 1122: 33 IMU lines
# HR id 1123: 38 IMU lines
# HR id 1124: 18 IMU lines
# HR id 1125: 17 IMU lines
# HR id 1126: 13 IMU lines
# HR id 1127: 29 IMU lines
# HR id 1128: 29 IMU lines
# HR id 1129: 29 IMU lines
# HR id 1130: 28 IMU lines
# HR id 1131: 14 IMU lines
# HR id 1132: 17 IMU lines
# HR id 1133: 18 IMU lines
# HR id 1134: 13 IMU lines
# HR id 1135: 25 IMU lines
# HR id 1136: 32 IMU lines
# HR id 1137: 36 IMU lines
# HR id 1138: 21 IMU lines
# HR id 1139: 14 IMU lines
# HR id 1140: 15 IMU lines
# HR id 1141: 28 IMU lines
# HR id 1142: 13 IMU lines
# HR id 1143: 16 IMU lines
# HR id 1144: 33 IMU lines
# HR id 1145: 24 IMU lines
# HR id 1146: 14 IMU lines
# HR id 1147: 15 IMU lines
# HR id 1148: 20 IMU lines
# HR id 1149: 36 IMU lines
# HR id 1150: 28 IMU lines
# HR id 1151: 28 IMU lines
# HR id 1152: 15 IMU lines
# HR id 1153: 13 IMU lines
# HR id 1154: 25 IMU lines
# HR id 1155: 32 IMU lines
# HR id 1156: 26 IMU lines
# HR id 1157: 13 IMU lines
# HR id 1158: 15 IMU lines
# HR id 1159: 27 IMU lines
# HR id 1160: 28 IMU lines
# HR id 1161: 27 IMU lines
# HR id 1162: 13 IMU lines
# HR id 1163: 14 IMU lines
# HR id 1164: 18 IMU lines
# HR id 1165: 13 IMU lines
# HR id 1166: 24 IMU lines
# HR id 1167: 28 IMU lines
# HR id 1168: 28 IMU lines
# HR id 1169: 14 IMU lines
# HR id 1170: 13 IMU lines
# HR id 1171: 25 IMU lines
# HR id 1172: 31 IMU lines
# HR id 1173: 26 IMU lines
# HR id 1174: 14 IMU lines
# HR id 1175: 14 IMU lines
# HR id 1176: 27 IMU lines
# HR id 1177: 28 IMU lines
# HR id 1178: 35 IMU lines
# HR id 1179: 19 IMU lines
# HR id 1180: 17 IMU lines
# HR id 1181: 13 IMU lines
# HR id 1182: 24 IMU lines
# HR id 1183: 30 IMU lines
# HR id 1184: 25 IMU lines
# HR id 1185: 14 IMU lines
# HR id 1186: 14 IMU lines
# HR id 1187: 23 IMU lines
# HR id 1188: 33 IMU lines
# HR id 1189: 25 IMU lines
# HR id 1190: 13 IMU lines
# HR id 1191: 14 IMU lines
# HR id 1192: 20 IMU lines
# HR id 1193: 35 IMU lines
# HR id 1194: 27 IMU lines
# HR id 1195: 12 IMU lines
# HR id 1196: 16 IMU lines
# HR id 1197: 18 IMU lines
# HR id 1198: 35 IMU lines
# HR id 1199: 28 IMU lines
# HR id 1200: 28 IMU lines
# HR id 1201: 16 IMU lines
# HR id 1202: 13 IMU lines
# HR id 1203: 24 IMU lines
# HR id 1204: 31 IMU lines
# HR id 1205: 26 IMU lines
# HR id 1206: 13 IMU lines
# HR id 1207: 16 IMU lines
# HR id 1208: 28 IMU lines
# HR id 1209: 27 IMU lines
# HR id 1210: 31 IMU lines
# HR id 1211: 25 IMU lines
# HR id 1212: 13 IMU lines
# HR id 1213: 16 IMU lines
# HR id 1214: 20 IMU lines
# HR id 1215: 36 IMU lines
# HR id 1216: 35 IMU lines
# HR id 1217: 19 IMU lines
# HR id 1218: 17 IMU lines
# HR id 1219: 36 IMU lines
# HR id 1220: 27 IMU lines
# HR id 1221: 26 IMU lines
# HR id 1222: 17 IMU lines
# HR id 1223: 13 IMU lines
# HR id 1224: 23 IMU lines
# HR id 1225: 34 IMU lines
# HR id 1226: 21 IMU lines
# HR id 1227: 15 IMU lines
# HR id 1228: 13 IMU lines
# HR id 1229: 24 IMU lines
# HR id 1230: 34 IMU lines
# HR id 1231: 18 IMU lines
# HR id 1232: 16 IMU lines
# HR id 1233: 13 IMU lines
# HR id 1234: 23 IMU lines
# HR id 1235: 35 IMU lines
# HR id 1236: 18 IMU lines
# HR id 1237: 25 IMU lines
# HR id 1238: 27 IMU lines
# HR id 1239: 24 IMU lines
# HR id 1240: 14 IMU lines
# HR id 1241: 13 IMU lines
# HR id 1242: 23 IMU lines
# HR id 1243: 29 IMU lines
# HR id 1244: 25 IMU lines
# HR id 1245: 14 IMU lines
# HR id 1246: 13 IMU lines
# HR id 1247: 23 IMU lines
# HR id 1248: 35 IMU lines
# HR id 1249: 17 IMU lines
# HR id 1250: 19 IMU lines
# HR id 1251: 34 IMU lines
# HR id 1252: 24 IMU lines
# HR id 1253: 26 IMU lines
# HR id 1254: 27 IMU lines
# HR id 1255: 26 IMU lines
# HR id 1256: 26 IMU lines
# HR id 1257: 24 IMU lines
# HR id 1258: 30 IMU lines
# HR id 1259: 25 IMU lines
# HR id 1260: 14 IMU lines
# HR id 1261: 13 IMU lines
# HR id 1262: 25 IMU lines
# HR id 1263: 26 IMU lines
# HR id 1264: 28 IMU lines
# HR id 1265: 26 IMU lines
# HR id 1266: 27 IMU lines
# HR id 1267: 27 IMU lines
# HR id 1268: 27 IMU lines
# HR id 1269: 26 IMU lines
# HR id 1270: 27 IMU lines
# HR id 1271: 27 IMU lines
# HR id 1272: 28 IMU lines
# HR id 1273: 27 IMU lines
# HR id 1274: 27 IMU lines
# HR id 1275: 27 IMU lines
# HR id 1276: 27 IMU lines
# HR id 1277: 28 IMU lines
# HR id 1278: 27 IMU lines
# HR id 1279: 27 IMU lines
# HR id 1280: 28 IMU lines
# HR id 1281: 27 IMU lines
# HR id 1282: 26 IMU lines
# HR id 1283: 28 IMU lines
# HR id 1284: 27 IMU lines
# HR id 1285: 28 IMU lines
# HR id 1286: 27 IMU lines
# HR id 1287: 27 IMU lines
# HR id 1288: 28 IMU lines
# HR id 1289: 27 IMU lines
# HR id 1290: 29 IMU lines
# HR id 1291: 28 IMU lines
# HR id 1292: 26 IMU lines
# HR id 1293: 29 IMU lines
# HR id 1294: 31 IMU lines
# HR id 1295: 30 IMU lines
# HR id 1296: 29 IMU lines
# HR id 1297: 30 IMU lines
# HR id 1298: 31 IMU lines
# HR id 1299: 32 IMU lines
# HR id 1300: 30 IMU lines
# HR id 1301: 31 IMU lines
# HR id 1302: 31 IMU lines
# ...
# HR id 722: 21 IMU lines
# HR id 723: 23 IMU lines
# HR id 724: 24 IMU lines
# HR id 725: 22 IMU lines
# HR id 726: 23 IMU lines
# HR id 727: 23 IMU lines
# HR id 728: 22 IMU lines
# HR id 729: 24 IMU lines
# HR id 730: 23 IMU lines
# HR id 731: 23 IMU lines
# HR id 732: 22 IMU lines
# HR id 733: 23 IMU lines
# HR id 734: 23 IMU lines
# HR id 735: 23 IMU lines
# HR id 736: 23 IMU lines
# HR id 737: 22 IMU lines
# HR id 738: 24 IMU lines
# HR id 739: 24 IMU lines
# HR id 740: 22 IMU lines
# HR id 741: 23 IMU lines
# HR id 742: 23 IMU lines
# HR id 743: 39 IMU lines
# HR id 744: 14 IMU lines
# HR id 745: 13 IMU lines
# HR id 746: 20 IMU lines
# HR id 747: 23 IMU lines
# HR id 748: 25 IMU lines
# HR id 749: 22 IMU lines
# HR id 750: 25 IMU lines
# HR id 751: 24 IMU lines
# HR id 752: 23 IMU lines
# HR id 753: 24 IMU lines
# HR id 754: 23 IMU lines
# HR id 755: 24 IMU lines
# HR id 756: 25 IMU lines
# HR id 757: 23 IMU lines
# HR id 758: 24 IMU lines
# HR id 759: 25 IMU lines
# HR id 760: 23 IMU lines
# HR id 761: 24 IMU lines
# HR id 762: 25 IMU lines
# HR id 763: 24 IMU lines
# HR id 764: 24 IMU lines
# HR id 765: 24 IMU lines
# HR id 766: 24 IMU lines
# HR id 767: 25 IMU lines
# HR id 768: 23 IMU lines
# HR id 769: 25 IMU lines
# HR id 770: 25 IMU lines
# HR id 771: 23 IMU lines
# HR id 772: 26 IMU lines
# HR id 773: 24 IMU lines
# HR id 774: 24 IMU lines
# HR id 775: 25 IMU lines
# HR id 776: 24 IMU lines
# HR id 777: 26 IMU lines
# HR id 778: 23 IMU lines
# HR id 779: 25 IMU lines
# HR id 780: 24 IMU lines
# HR id 781: 24 IMU lines
# HR id 782: 13 IMU lines
# HR id 783: 13 IMU lines
# HR id 784: 23 IMU lines
# HR id 785: 25 IMU lines
# HR id 786: 23 IMU lines
# HR id 787: 25 IMU lines
# HR id 788: 24 IMU lines
# HR id 789: 25 IMU lines
# HR id 790: 24 IMU lines
# HR id 791: 24 IMU lines
# HR id 792: 25 IMU lines
# HR id 793: 24 IMU lines
# HR id 794: 25 IMU lines
# HR id 795: 25 IMU lines
# HR id 796: 24 IMU lines
# HR id 797: 25 IMU lines
# HR id 798: 24 IMU lines
# HR id 799: 25 IMU lines
# HR id 800: 25 IMU lines
# HR id 801: 25 IMU lines
# HR id 802: 24 IMU lines
# HR id 803: 25 IMU lines
# HR id 804: 24 IMU lines
# HR id 805: 25 IMU lines
# HR id 806: 26 IMU lines
# HR id 807: 24 IMU lines
# HR id 808: 25 IMU lines
# HR id 809: 26 IMU lines
# HR id 810: 24 IMU lines
# HR id 811: 26 IMU lines
# HR id 812: 25 IMU lines
# HR id 813: 26 IMU lines
# HR id 814: 24 IMU lines
# HR id 815: 27 IMU lines
# HR id 816: 25 IMU lines
# HR id 817: 24 IMU lines
# HR id 818: 27 IMU lines
# HR id 819: 24 IMU lines
# HR id 820: 26 IMU lines
# HR id 821: 25 IMU lines
# HR id 822: 26 IMU lines
# HR id 823: 25 IMU lines
# HR id 824: 26 IMU lines
# HR id 825: 25 IMU lines
# HR id 826: 24 IMU lines
# HR id 827: 26 IMU lines
# HR id 828: 25 IMU lines
# HR id 829: 25 IMU lines
# HR id 830: 25 IMU lines
# HR id 831: 24 IMU lines
# HR id 832: 25 IMU lines
# HR id 833: 26 IMU lines
# HR id 834: 25 IMU lines
# HR id 835: 24 IMU lines
# HR id 836: 13 IMU lines
# HR id 837: 39 IMU lines
# HR id 838: 19 IMU lines
# HR id 839: 18 IMU lines
# HR id 840: 37 IMU lines
# HR id 841: 55 IMU lines
# HR id 842: 18 IMU lines
# HR id 843: 36 IMU lines
# HR id 844: 19 IMU lines
# HR id 845: 18 IMU lines
# HR id 846: 41 IMU lines
# HR id 847: 17 IMU lines
# HR id 848: 19 IMU lines
# HR id 849: 17 IMU lines
# HR id 850: 18 IMU lines
# HR id 851: 17 IMU lines
# HR id 852: 20 IMU lines
# HR id 853: 17 IMU lines
# HR id 854: 37 IMU lines
# HR id 855: 17 IMU lines
# HR id 856: 20 IMU lines
# HR id 857: 23 IMU lines
# HR id 858: 35 IMU lines
# HR id 859: 18 IMU lines
# HR id 860: 17 IMU lines
# HR id 861: 18 IMU lines
# HR id 862: 17 IMU lines
# HR id 863: 21 IMU lines
# HR id 864: 22 IMU lines
# HR id 865: 17 IMU lines
# HR id 866: 36 IMU lines
# HR id 867: 14 IMU lines
# HR id 868: 19 IMU lines
# HR id 869: 19 IMU lines
# HR id 870: 33 IMU lines
# HR id 871: 20 IMU lines
# HR id 872: 13 IMU lines
# HR id 873: 36 IMU lines
# HR id 874: 17 IMU lines
# HR id 875: 15 IMU lines
# HR id 876: 34 IMU lines
# HR id 877: 37 IMU lines
# HR id 878: 65 IMU lines
# HR id 879: 19 IMU lines
# HR id 880: 33 IMU lines
# HR id 881: 17 IMU lines
# HR id 882: 18 IMU lines
# HR id 883: 22 IMU lines
# HR id 884: 14 IMU lines
# HR id 885: 23 IMU lines
# HR id 886: 28 IMU lines
# HR id 887: 23 IMU lines
# HR id 888: 23 IMU lines
# HR id 889: 23 IMU lines
# HR id 890: 21 IMU lines
# HR id 891: 20 IMU lines
# HR id 892: 23 IMU lines
# HR id 893: 22 IMU lines
# HR id 894: 21 IMU lines
# HR id 895: 24 IMU lines
# HR id 896: 21 IMU lines
# HR id 897: 23 IMU lines
# HR id 898: 22 IMU lines
# HR id 899: 21 IMU lines
# HR id 900: 22 IMU lines
# HR id 901: 23 IMU lines
# HR id 902: 22 IMU lines
# HR id 903: 22 IMU lines
#
# Average IMU lines per HR line: 23.26
# HR id 903 had 22 IMU lines
#
# Saved IMU CSV with hr_id to: imu_hr_aligned_level2.csv
# Number of IMU lines per HR id:
# HR id 0: 27 IMU lines
# HR id 1: 27 IMU lines
# HR id 2: 26 IMU lines
# HR id 3: 26 IMU lines
# HR id 4: 26 IMU lines
# HR id 5: 27 IMU lines
# HR id 6: 27 IMU lines
# HR id 7: 26 IMU lines
# HR id 8: 13 IMU lines
# HR id 9: 14 IMU lines
# HR id 10: 61 IMU lines
# HR id 11: 62 IMU lines
# HR id 12: 15 IMU lines
# HR id 13: 35 IMU lines
# HR id 14: 16 IMU lines
# HR id 15: 32 IMU lines
# HR id 22: 12 IMU lines
# HR id 25: 14 IMU lines
# HR id 26: 19 IMU lines
# HR id 27: 34 IMU lines
# HR id 28: 18 IMU lines
# HR id 29: 39 IMU lines
# HR id 30: 24 IMU lines
# HR id 31: 23 IMU lines
# HR id 32: 39 IMU lines
# HR id 33: 18 IMU lines
# HR id 34: 38 IMU lines
# HR id 35: 39 IMU lines
# HR id 36: 19 IMU lines
# HR id 37: 37 IMU lines
# HR id 38: 69 IMU lines
# HR id 39: 20 IMU lines
# HR id 40: 19 IMU lines
# HR id 41: 17 IMU lines
# HR id 42: 53 IMU lines
# HR id 43: 22 IMU lines
# HR id 44: 17 IMU lines
# HR id 45: 13 IMU lines
# HR id 46: 19 IMU lines
# HR id 47: 24 IMU lines
# HR id 48: 14 IMU lines
# HR id 49: 19 IMU lines
# HR id 50: 27 IMU lines
# HR id 51: 31 IMU lines
# HR id 52: 14 IMU lines
# HR id 53: 12 IMU lines
# HR id 54: 13 IMU lines
# HR id 55: 17 IMU lines
# HR id 56: 29 IMU lines
# HR id 57: 72 IMU lines
# HR id 58: 25 IMU lines
# HR id 59: 14 IMU lines
# HR id 60: 24 IMU lines
# HR id 61: 36 IMU lines
# HR id 62: 55 IMU lines
# HR id 63: 17 IMU lines
# HR id 64: 19 IMU lines
# HR id 65: 18 IMU lines
# HR id 66: 10 IMU lines
# HR id 73: 13 IMU lines
# HR id 74: 38 IMU lines
# HR id 75: 32 IMU lines
# HR id 76: 22 IMU lines
# HR id 77: 24 IMU lines
# HR id 78: 31 IMU lines
# HR id 79: 27 IMU lines
# HR id 80: 13 IMU lines
# HR id 81: 20 IMU lines
# HR id 82: 28 IMU lines
# HR id 83: 13 IMU lines
# HR id 84: 16 IMU lines
# HR id 85: 32 IMU lines
# HR id 86: 31 IMU lines
# HR id 87: 21 IMU lines
# HR id 88: 14 IMU lines
# HR id 89: 22 IMU lines
# HR id 90: 58 IMU lines
# HR id 91: 27 IMU lines
# HR id 92: 20 IMU lines
# HR id 93: 38 IMU lines
# HR id 94: 30 IMU lines
# HR id 95: 18 IMU lines
# HR id 96: 21 IMU lines
# HR id 97: 15 IMU lines
# HR id 98: 16 IMU lines
# HR id 99: 21 IMU lines
# HR id 100: 19 IMU lines
# HR id 101: 36 IMU lines
# HR id 102: 75 IMU lines
# HR id 103: 37 IMU lines
# HR id 104: 16 IMU lines
# HR id 105: 20 IMU lines
# HR id 106: 17 IMU lines
# HR id 107: 20 IMU lines
# HR id 108: 17 IMU lines
# HR id 109: 16 IMU lines
# HR id 110: 16 IMU lines
# HR id 111: 35 IMU lines
# HR id 112: 35 IMU lines
# HR id 113: 22 IMU lines
# HR id 114: 15 IMU lines
# HR id 115: 21 IMU lines
# HR id 116: 17 IMU lines
# HR id 117: 17 IMU lines
# HR id 118: 16 IMU lines
# HR id 119: 20 IMU lines
# HR id 120: 20 IMU lines
# HR id 121: 88 IMU lines
# HR id 122: 17 IMU lines
# HR id 123: 18 IMU lines
# HR id 124: 17 IMU lines
# HR id 125: 17 IMU lines
# HR id 126: 17 IMU lines
# HR id 127: 17 IMU lines
# HR id 128: 19 IMU lines
# HR id 129: 24 IMU lines
# HR id 130: 17 IMU lines
# HR id 131: 19 IMU lines
# HR id 132: 13 IMU lines
# HR id 133: 17 IMU lines
# HR id 134: 13 IMU lines
# HR id 135: 16 IMU lines
# HR id 136: 17 IMU lines
# HR id 137: 13 IMU lines
# HR id 138: 13 IMU lines
# HR id 139: 14 IMU lines
# HR id 140: 40 IMU lines
# HR id 141: 19 IMU lines
# HR id 142: 59 IMU lines
# HR id 143: 36 IMU lines
# HR id 148: 1 IMU lines
# HR id 149: 23 IMU lines
# HR id 150: 21 IMU lines
# HR id 151: 18 IMU lines
# HR id 152: 19 IMU lines
# HR id 153: 41 IMU lines
# HR id 154: 18 IMU lines
# HR id 155: 20 IMU lines
# HR id 156: 21 IMU lines
# HR id 157: 19 IMU lines
# HR id 158: 20 IMU lines
# HR id 159: 19 IMU lines
# HR id 160: 21 IMU lines
# HR id 161: 19 IMU lines
# HR id 162: 20 IMU lines
# HR id 163: 20 IMU lines
# HR id 164: 20 IMU lines
# HR id 165: 20 IMU lines
# HR id 166: 20 IMU lines
# HR id 167: 19 IMU lines
# HR id 168: 21 IMU lines
# HR id 169: 20 IMU lines
# HR id 170: 20 IMU lines
# HR id 171: 20 IMU lines
# HR id 172: 21 IMU lines
# HR id 173: 20 IMU lines
# HR id 174: 19 IMU lines
# HR id 175: 20 IMU lines
# HR id 176: 21 IMU lines
# HR id 177: 19 IMU lines
# HR id 178: 20 IMU lines
# HR id 179: 20 IMU lines
# HR id 180: 21 IMU lines
# HR id 181: 21 IMU lines
# HR id 182: 19 IMU lines
# HR id 183: 21 IMU lines
# HR id 184: 20 IMU lines
# HR id 185: 20 IMU lines
# HR id 186: 21 IMU lines
# HR id 187: 20 IMU lines
# HR id 188: 20 IMU lines
# HR id 189: 21 IMU lines
# HR id 190: 20 IMU lines
# HR id 191: 21 IMU lines
# HR id 192: 29 IMU lines
# HR id 193: 13 IMU lines
# HR id 194: 13 IMU lines
# HR id 195: 18 IMU lines
# HR id 196: 18 IMU lines
# HR id 197: 16 IMU lines
# HR id 198: 27 IMU lines
# HR id 199: 20 IMU lines
# HR id 200: 17 IMU lines
# HR id 201: 22 IMU lines
# HR id 202: 18 IMU lines
# HR id 203: 13 IMU lines
# HR id 204: 28 IMU lines
# HR id 205: 41 IMU lines
# HR id 206: 45 IMU lines
# HR id 207: 30 IMU lines
# HR id 208: 36 IMU lines
# HR id 209: 19 IMU lines
# HR id 210: 22 IMU lines
# HR id 211: 18 IMU lines
# HR id 212: 18 IMU lines
# HR id 213: 14 IMU lines
# HR id 214: 8 IMU lines
# HR id 218: 19 IMU lines
# HR id 219: 18 IMU lines
# HR id 220: 13 IMU lines
# HR id 221: 44 IMU lines
# HR id 222: 21 IMU lines
# HR id 223: 22 IMU lines
# HR id 224: 14 IMU lines
# HR id 225: 21 IMU lines
# HR id 226: 20 IMU lines
# HR id 227: 20 IMU lines
# HR id 228: 18 IMU lines
# HR id 229: 17 IMU lines
# HR id 230: 23 IMU lines
# HR id 231: 14 IMU lines
# HR id 232: 17 IMU lines
# HR id 233: 56 IMU lines
# HR id 234: 21 IMU lines
# HR id 235: 14 IMU lines
# HR id 236: 18 IMU lines
# HR id 237: 20 IMU lines
# HR id 238: 18 IMU lines
# HR id 239: 17 IMU lines
# HR id 240: 17 IMU lines
# HR id 241: 21 IMU lines
# HR id 242: 16 IMU lines
# HR id 243: 19 IMU lines
# HR id 244: 18 IMU lines
# HR id 245: 17 IMU lines
# HR id 246: 21 IMU lines
# HR id 247: 16 IMU lines
# HR id 248: 19 IMU lines
# HR id 249: 36 IMU lines
# HR id 250: 16 IMU lines
# HR id 251: 21 IMU lines
# HR id 252: 17 IMU lines
# HR id 253: 19 IMU lines
# HR id 254: 17 IMU lines
# HR id 255: 18 IMU lines
# HR id 256: 17 IMU lines
# HR id 257: 19 IMU lines
# HR id 258: 17 IMU lines
# HR id 259: 21 IMU lines
# HR id 260: 16 IMU lines
# HR id 261: 17 IMU lines
# HR id 262: 38 IMU lines
# HR id 263: 17 IMU lines
# HR id 264: 20 IMU lines
# HR id 265: 18 IMU lines
# HR id 266: 15 IMU lines
# HR id 267: 20 IMU lines
# HR id 268: 16 IMU lines
# HR id 269: 18 IMU lines
# HR id 270: 27 IMU lines
# HR id 271: 20 IMU lines
# HR id 272: 20 IMU lines
# HR id 273: 19 IMU lines
# HR id 274: 21 IMU lines
# HR id 275: 16 IMU lines
# HR id 276: 17 IMU lines
# HR id 277: 22 IMU lines
# HR id 278: 19 IMU lines
# HR id 279: 18 IMU lines
# HR id 280: 19 IMU lines
# HR id 281: 18 IMU lines
# HR id 282: 18 IMU lines
# HR id 283: 20 IMU lines
# HR id 284: 15 IMU lines
# HR id 285: 21 IMU lines
# HR id 286: 35 IMU lines
# HR id 287: 36 IMU lines
# HR id 288: 16 IMU lines
# HR id 289: 5 IMU lines
# HR id 295: 20 IMU lines
# HR id 296: 19 IMU lines
# HR id 297: 20 IMU lines
# HR id 298: 19 IMU lines
# HR id 299: 19 IMU lines
# HR id 300: 20 IMU lines
# HR id 301: 19 IMU lines
# HR id 302: 19 IMU lines
# HR id 303: 20 IMU lines
# HR id 304: 21 IMU lines
# HR id 305: 19 IMU lines
# HR id 306: 19 IMU lines
# HR id 307: 20 IMU lines
# HR id 308: 20 IMU lines
# HR id 309: 19 IMU lines
# HR id 310: 21 IMU lines
# HR id 311: 18 IMU lines
# HR id 312: 20 IMU lines
# HR id 313: 20 IMU lines
# HR id 314: 21 IMU lines
# HR id 315: 19 IMU lines
# HR id 316: 20 IMU lines
# HR id 317: 19 IMU lines
# HR id 318: 21 IMU lines
# HR id 319: 19 IMU lines
# HR id 320: 19 IMU lines
# HR id 321: 21 IMU lines
# HR id 322: 19 IMU lines
# HR id 323: 19 IMU lines
# HR id 324: 21 IMU lines
# HR id 325: 20 IMU lines
# HR id 326: 19 IMU lines
# HR id 327: 19 IMU lines
# HR id 328: 20 IMU lines
# HR id 329: 20 IMU lines
# HR id 330: 20 IMU lines
# HR id 331: 20 IMU lines
# HR id 332: 20 IMU lines
# HR id 333: 20 IMU lines
# HR id 334: 20 IMU lines
# HR id 335: 20 IMU lines
# HR id 336: 19 IMU lines
# HR id 337: 20 IMU lines
# HR id 338: 21 IMU lines
# HR id 339: 19 IMU lines
# HR id 340: 21 IMU lines
# HR id 341: 19 IMU lines
# HR id 342: 20 IMU lines
# HR id 343: 20 IMU lines
# HR id 344: 20 IMU lines
# HR id 345: 21 IMU lines
# HR id 346: 20 IMU lines
# HR id 347: 20 IMU lines
# HR id 348: 21 IMU lines
# HR id 349: 19 IMU lines
# HR id 350: 21 IMU lines
# HR id 351: 19 IMU lines
# HR id 352: 21 IMU lines
# HR id 353: 20 IMU lines
# HR id 354: 20 IMU lines
# HR id 355: 20 IMU lines
# HR id 356: 21 IMU lines
# HR id 357: 20 IMU lines
# HR id 358: 20 IMU lines
# HR id 359: 20 IMU lines
# HR id 360: 21 IMU lines
# HR id 361: 21 IMU lines
# HR id 362: 20 IMU lines
# HR id 363: 21 IMU lines
# HR id 364: 20 IMU lines
# HR id 365: 22 IMU lines
# HR id 366: 21 IMU lines
# HR id 367: 20 IMU lines
# HR id 368: 20 IMU lines
# HR id 369: 22 IMU lines
# HR id 370: 2 IMU lines
# HR id 376: 20 IMU lines
# HR id 377: 21 IMU lines
# HR id 378: 20 IMU lines
# HR id 379: 21 IMU lines
# HR id 380: 21 IMU lines
# HR id 381: 21 IMU lines
# HR id 382: 21 IMU lines
# HR id 383: 21 IMU lines
# HR id 384: 22 IMU lines
# HR id 385: 20 IMU lines
# HR id 386: 21 IMU lines
# HR id 387: 22 IMU lines
# HR id 388: 21 IMU lines
# HR id 389: 21 IMU lines
# HR id 390: 21 IMU lines
# HR id 391: 22 IMU lines
# HR id 392: 21 IMU lines
# HR id 393: 22 IMU lines
# HR id 394: 21 IMU lines
# HR id 395: 23 IMU lines
# HR id 396: 21 IMU lines
# HR id 397: 21 IMU lines
# HR id 398: 22 IMU lines
# HR id 399: 22 IMU lines
# HR id 400: 21 IMU lines
# HR id 401: 23 IMU lines
# HR id 402: 23 IMU lines
# HR id 403: 21 IMU lines
# HR id 404: 23 IMU lines
# HR id 405: 22 IMU lines
# HR id 406: 22 IMU lines
# HR id 407: 23 IMU lines
# HR id 408: 22 IMU lines
# HR id 409: 23 IMU lines
# HR id 410: 23 IMU lines
# HR id 411: 22 IMU lines
# HR id 412: 23 IMU lines
# HR id 413: 21 IMU lines
# HR id 414: 23 IMU lines
# HR id 415: 23 IMU lines
# HR id 416: 23 IMU lines
# HR id 417: 22 IMU lines
# HR id 418: 22 IMU lines
# HR id 419: 23 IMU lines
# HR id 420: 23 IMU lines
# HR id 421: 22 IMU lines
# HR id 422: 22 IMU lines
# HR id 423: 24 IMU lines
# HR id 424: 23 IMU lines
# HR id 425: 21 IMU lines
# HR id 426: 23 IMU lines
# HR id 427: 23 IMU lines
# HR id 428: 22 IMU lines
# HR id 429: 23 IMU lines
# HR id 430: 23 IMU lines
# HR id 431: 22 IMU lines
# HR id 432: 23 IMU lines
# HR id 433: 23 IMU lines
# HR id 434: 23 IMU lines
# HR id 435: 22 IMU lines
# HR id 436: 23 IMU lines
# HR id 437: 24 IMU lines
# HR id 438: 22 IMU lines
# HR id 439: 22 IMU lines
# HR id 440: 24 IMU lines
# HR id 441: 23 IMU lines
# HR id 442: 22 IMU lines
# HR id 443: 23 IMU lines
# HR id 444: 23 IMU lines
# HR id 445: 22 IMU lines
# HR id 446: 24 IMU lines
# HR id 447: 22 IMU lines
# HR id 448: 23 IMU lines
# HR id 449: 23 IMU lines
# HR id 450: 23 IMU lines
# HR id 451: 23 IMU lines
# HR id 452: 24 IMU lines
# HR id 453: 23 IMU lines
# HR id 454: 23 IMU lines
# HR id 455: 22 IMU lines
# HR id 456: 23 IMU lines
# HR id 457: 24 IMU lines
# HR id 458: 23 IMU lines
# HR id 459: 25 IMU lines
# HR id 460: 24 IMU lines
# HR id 461: 24 IMU lines
# HR id 462: 23 IMU lines
# HR id 463: 25 IMU lines
# HR id 464: 23 IMU lines
# HR id 465: 24 IMU lines
# HR id 466: 24 IMU lines
# HR id 467: 23 IMU lines
# HR id 468: 24 IMU lines
# HR id 469: 23 IMU lines
# HR id 470: 25 IMU lines
# HR id 471: 22 IMU lines
# HR id 472: 24 IMU lines
# HR id 473: 24 IMU lines
# HR id 474: 23 IMU lines
# HR id 475: 24 IMU lines
# HR id 476: 22 IMU lines
# HR id 477: 25 IMU lines
# HR id 478: 23 IMU lines
# HR id 479: 23 IMU lines
# HR id 480: 24 IMU lines
# HR id 481: 24 IMU lines
# HR id 482: 23 IMU lines
# HR id 483: 23 IMU lines
# HR id 484: 23 IMU lines
# HR id 485: 24 IMU lines
# HR id 486: 23 IMU lines
# HR id 487: 24 IMU lines
# HR id 488: 24 IMU lines
# HR id 489: 23 IMU lines
# HR id 490: 24 IMU lines
# HR id 491: 24 IMU lines
# HR id 492: 23 IMU lines
# HR id 493: 25 IMU lines
# HR id 494: 22 IMU lines
# HR id 495: 24 IMU lines
# HR id 496: 24 IMU lines
# HR id 497: 24 IMU lines
# HR id 498: 24 IMU lines
# HR id 499: 22 IMU lines
# HR id 500: 24 IMU lines
# HR id 501: 24 IMU lines
# HR id 502: 24 IMU lines
# HR id 503: 24 IMU lines
# HR id 504: 24 IMU lines
# HR id 505: 23 IMU lines
# HR id 506: 24 IMU lines
# HR id 507: 24 IMU lines
#
# Average IMU lines per HR line: 22.26
# HR id 507 had 24 IMU lines
#
# Saved IMU CSV with hr_id to: imu_hr_aligned_level3.csv

# %% [markdown]
# Cell 5 : Calculating the aggregated feature of imu for every hr

# %%
def generate_aggregated_imu_csv(imu_hr_csv, output_aggregated_csv):
    """
    Generates a new IMU CSV with aggregated features for each HR ID
    and keeps the existing fatigue_level from the input file.

    Parameters:
        imu_hr_csv (str): Path to IMU CSV with hr_id and fatigue_level columns
        output_aggregated_csv (str): Path to save aggregated CSV
    """
    # Load the IMU CSV with HR IDs and fatigue_level
    imu_df = pd.read_csv(imu_hr_csv)

    # Filter out unassigned IMU lines (hr_id = -1)
    imu_df = imu_df[imu_df['hr_id'] != -1]

    # Define IMU features
    imu_features = ['ax', 'ay', 'az', 'gx', 'gy', 'gz']

    aggregated_data = []

    # Group by hr_id
    for hr_id, group in imu_df.groupby('hr_id'):

        row = {'hr_id': hr_id}

        # Aggregate IMU features
        for feature in imu_features:
            feature_data = group[feature]

            row[f'{feature}_mean'] = feature_data.mean()
            row[f'{feature}_std'] = feature_data.std()
            row[f'{feature}_min'] = feature_data.min()
            row[f'{feature}_max'] = feature_data.max()
            row[f'{feature}_median'] = feature_data.median()

        # Count the original IMU rows
        row['imu_line_count'] = len(group)

        #  KEEP the existing fatigue level (same for all rows in group)
        row['fatigue_level'] = group['fatigue_level'].iloc[0]

        aggregated_data.append(row)

    # Convert to DataFrame
    aggregated_df = pd.DataFrame(aggregated_data)

    # Reorder columns
    columns_order = ['hr_id', 'imu_line_count']
    for feature in imu_features:
        columns_order.extend([
            f'{feature}_mean', f'{feature}_std', f'{feature}_min',
            f'{feature}_max', f'{feature}_median'
        ])
    columns_order.append("fatigue_level")

    aggregated_df = aggregated_df[columns_order]

    # Save output
    aggregated_df.to_csv(output_aggregated_csv, index=False)

    print(f"Saved aggregated IMU features to: {output_aggregated_csv}")
    print(f"Rows: {len(aggregated_df)}")
    print(aggregated_df.head())

    return aggregated_df

print("Processing level 0 file:")
generate_aggregated_imu_csv(
    "imu_hr_aligned_level0.csv",
    "imu_aggregated_features_level0.csv"
)
print("\n" + "="*50 + "\n")

print("Processing level 1 file:")
generate_aggregated_imu_csv(
    "imu_hr_aligned_level1.csv",
    "imu_aggregated_features_level1.csv"
)

print("\n" + "="*50 + "\n")
print("Processing level 2 file:")
generate_aggregated_imu_csv(
    "imu_hr_aligned_level2.csv",
    "imu_aggregated_features_level2.csv"
)
print("\n" + "="*50 + "\n")
print("Processing level 3 file:")
generate_aggregated_imu_csv(
    "imu_hr_aligned_level3.csv",
    "imu_aggregated_features_level3.csv"
)
# Out:
# Processing level 0 file:
# Saved aggregated IMU features to: imu_aggregated_features_level0.csv
# Rows: 685
#    hr_id  imu_line_count   ax_mean    ax_std    ax_min    ax_max  ax_median  \
# 0      0              50  4.902734  0.040123  4.800174  4.993999   4.903069
# 1      1              48  4.921514  0.038802  4.826496  5.003571   4.928194
# 2      2              49  4.883877  0.034966  4.814531  4.941355   4.883925
# 3      3              49  4.905217  0.034481  4.809745  4.970070   4.907855
# 4      4              47  4.929442  0.030109  4.869568  4.984427   4.934176
#
#     ay_mean    ay_std    ay_min  ...    gy_std  gy_min  gy_max  gy_median  \
# 0 -8.621839  0.061099 -8.803509  ...  1.462259   -5.67    3.99     -2.100
# 1 -8.607440  0.054442 -8.750865  ...  1.251393   -4.83    2.66     -1.855
# 2 -8.639814  0.053915 -8.777187  ...  1.236608   -3.78    3.85     -1.960
# 3 -8.619841  0.050153 -8.791544  ...  1.450534   -6.09    2.24     -2.380
# 4 -8.608869  0.059698 -8.796330  ...  1.219068   -5.04    3.08     -1.960
#
#     gz_mean    gz_std  gz_min  gz_max  gz_median  fatigue_level
# 0 -1.517600  0.315734   -2.73   -0.91      -1.54              0
# 1 -0.898333  0.368807   -1.68   -0.28      -0.84              0
# 2 -0.982857  0.268825   -1.47   -0.28      -0.98              0
# 3 -1.545714  0.328278   -2.73   -0.63      -1.54              0
# 4 -1.015745  0.332799   -1.89   -0.42      -0.91              0
#
# [5 rows x 33 columns]
#
# ==================================================
#
# Processing level 1 file:
# Saved aggregated IMU features to: imu_aggregated_features_level1.csv
# Rows: 1654
#    hr_id  imu_line_count   ax_mean    ax_std    ax_min    ax_max  ax_median  \
# 0      0              30  1.844055  0.931672  0.043072  4.201947   1.823396
# 1      1              32  1.046374  1.345706 -2.608270  2.668093   1.468049
# 2      2              32  0.965239  2.173784 -3.474503  4.501060   1.371136
# 3      3              30  1.867266  1.896888 -2.132081  5.719050   1.667857
# 4      4              16  0.073283  2.028549 -2.620234  3.196925  -0.251255
#
#      ay_mean    ay_std     ay_min  ...     gy_std  gy_min  gy_max  gy_median  \
# 0  -9.708188  1.624784 -12.361763  ...  22.454458  -13.72   64.96   9.520000
# 1  -9.709075  2.566635 -16.113844  ...  35.667403  -43.89   59.15  10.255000
# 2  -9.639307  5.263037 -20.610117  ...  38.315958  -45.15   75.95  16.905000
# 3 -10.309525  6.129056 -20.078892  ...  57.038153  -75.74   75.18  14.210001
# 4 -10.922279  7.998816 -25.305002  ...  31.880260  -62.86   32.76 -30.695000
#
#     gz_mean     gz_std  gz_min  gz_max  gz_median  fatigue_level
# 0 -5.735333   5.358984  -18.13    2.94     -5.355              1
# 1  4.130000   7.788115  -11.76   15.75      4.585              1
# 2  1.218438  17.635285  -23.10   34.02      0.595              1
# 3 -6.027000  19.920724  -43.82   24.99     -3.780              1
# 4 -0.730625  13.407829  -35.70   26.39     -0.070              1
#
# [5 rows x 33 columns]
#
# ==================================================
#
# Processing level 2 file:
# Saved aggregated IMU features to: imu_aggregated_features_level2.csv
# Rows: 904
#    hr_id  imu_line_count   ax_mean    ax_std     ax_min    ax_max  ax_median  \
# 0      0              26 -2.336951  1.099358  -4.781030 -0.638907  -2.165582
# 1      1              27 -1.256809  1.135343  -2.943277  1.529068  -1.497960
# 2      2              26 -1.101750  3.912739 -10.650834  4.515418   0.191433
# 3      3              26 -0.047950  2.742471  -8.298605  5.070572   0.065805
# 4      4              37 -0.319486  4.288273 -10.586225  7.183510  -0.323043
#
#     ay_mean     ay_std    ay_min  ...     gy_std     gy_min  gy_max  \
# 0  9.440022   2.498388  5.180646  ...  20.317575  -54.39000   10.22
# 1  9.617275   3.066230  4.821710  ...  14.079301  -11.48000   40.32
# 2  9.263131   7.338249 -6.362742  ...  44.860494 -104.16000   39.34
# 3  9.916579  11.548451 -5.714264  ...  34.136976  -29.68000   86.24
# 4  8.190342  11.417681 -9.320377  ...  59.358398 -131.18001   87.99
#
#    gy_median    gz_mean     gz_std  gz_min  gz_max  gz_median  fatigue_level
# 0    -25.725   0.086154  19.414909  -43.05   19.11      9.100              2
# 1     19.950  10.746296  13.335793  -14.77   36.54     12.250              2
# 2     -5.740   2.237308  17.835379  -44.59   22.75      4.655              2
# 3     28.980  -4.940385  23.132840  -50.19   35.77     -2.835              2
# 4      0.490  -6.379460  23.483404  -37.94   46.76     -9.520              2
#
# [5 rows x 33 columns]
#
# ==================================================
#
# Processing level 3 file:
# Saved aggregated IMU features to: imu_aggregated_features_level3.csv
# Rows: 477
#    hr_id  imu_line_count    ax_mean    ax_std    ax_min     ax_max  ax_median  \
# 0      0              27   0.532555  0.368696  0.002393   1.174918   0.492939
# 1      1              27   1.070693  1.168401 -0.234505   5.027500   0.655657
# 2      2              26   6.597984  1.856233  4.254590  10.435472   6.407011
# 3      3              26   9.978979  0.554253  9.246197  11.182059   9.803744
# 4      4              26  10.126419  0.981265  9.021263  12.469444   9.644616
#
#     ay_mean    ay_std    ay_min  ...     gy_std  gy_min  gy_max  gy_median  \
# 0  9.701027  0.262069  9.148088  ...   4.003828    7.00   20.86     16.450
# 1  8.738457  0.788616  7.217011  ...   9.678909    2.87   31.99     12.390
# 2  6.364307  1.457071  4.134945  ...  20.952579   28.35   92.61     67.830
# 3  3.230886  0.727485  2.364193  ...   6.284675    3.50   30.10      5.985
# 4  3.053535  0.739487  2.237369  ...  16.425003  -54.25    3.57     -3.430
#
#      gz_mean     gz_std  gz_min  gz_max  gz_median  fatigue_level
# 0  16.626296   6.986967    6.51   29.26  18.130000              3
# 1  25.817037  17.697705   -0.56   50.26  30.240000              3
# 2  62.356539  14.748095   40.74   88.20  58.590002              3
# 3  14.961154   8.256975    3.15   37.24  13.265000              3
# 4  -7.250385   7.185947  -28.07    1.26  -4.095000              3
#
# [5 rows x 33 columns]
#      hr_id  imu_line_count    ax_mean    ax_std    ax_min     ax_max  \
# 0        0              27   0.532555  0.368696  0.002393   1.174918
# 1        1              27   1.070693  1.168401 -0.234505   5.027500
# 2        2              26   6.597984  1.856233  4.254590  10.435472
# 3        3              26   9.978979  0.554253  9.246197  11.182059
# 4        4              26  10.126419  0.981265  9.021263  12.469444
# ..     ...             ...        ...       ...       ...        ...
# 472    503              24  -2.805585  1.169533 -5.774087  -0.741802
# 473    504              24  -3.263927  1.116021 -4.778637  -0.308685
# 474    505              23  -1.632692  0.978374 -2.694415   0.373294
# 475    506              24  -2.815256  1.139763 -6.243097  -1.538640
# 476    507              24  -2.000571  1.333082 -4.398165   0.677193
#
#      ax_median   ay_mean    ay_std    ay_min  ...     gy_std  gy_min  gy_max  \
# 0     0.492939  9.701027  0.262069  9.148088  ...   4.003828    7.00   20.86
# 1     0.655657  8.738457  0.788616  7.217011  ...   9.678909    2.87   31.99
# 2     6.407011  6.364307  1.457071  4.134945  ...  20.952579   28.35   92.61
# 3     9.803744  3.230886  0.727485  2.364193  ...   6.284675    3.50   30.10
# 4     9.644616  3.053535  0.739487  2.237369  ...  16.425003  -54.25    3.57
# ..         ...       ...       ...       ...  ...        ...     ...     ...
# 472  -2.585537  9.121965  1.980125  6.915504  ...  16.986230  -47.04   28.35
# 473  -3.682685  8.829332  1.269167  6.882004  ...  12.671008  -52.29    3.71
# 474  -2.002864  8.868221  1.534216  6.015771  ...   9.532833    1.19   35.28
# 475  -2.414444  9.398146  2.225389  7.150009  ...  16.286055  -40.18   20.72
# 476  -1.813824  9.095942  1.622807  6.410601  ...  13.879815  -15.12   31.01
#
#      gy_median    gz_mean     gz_std     gz_min     gz_max  gz_median  \
# 0    16.450000  16.626296   6.986967   6.510000  29.260000  18.130000
# 1    12.390000  25.817037  17.697705  -0.560000  50.260000  30.240000
# 2    67.830000  62.356539  14.748095  40.740000  88.200000  58.590002
# 3     5.985000  14.961154   8.256975   3.150000  37.240000  13.265000
# 4    -3.430000  -7.250385   7.185947 -28.070000   1.260000  -4.095000
# ..         ...        ...        ...        ...        ...        ...
# 472  -5.075000 -10.365833  19.081343 -59.010002   7.840000  -2.450000
# 473 -18.060001  -0.545417   9.068222 -21.140000  11.200000   0.140000
# 474  28.420000  11.263913  10.375144 -16.660000  24.710001  13.790000
# 475 -23.660000  -1.105417  15.667576 -41.580000  12.600000   4.935000
# 476  10.500000  -2.193333  12.236552 -29.260000  12.320000   1.575000
#
#      fatigue_level
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# ..             ...
# 472              3
# 473              3
# 474              3
# 475              3
# 476              3
#
# [477 rows x 33 columns]

# %% [markdown]
# Cell 6 : Adding an id to the hr data

# %%
def add_hr_id_to_hr_csv(hr_csv_file, output_csv_file):
    """
    Adds an HR ID column to heart rate CSV file.
    HR ID starts from 0 and increments for each line.

    Parameters:
        hr_csv_file (str): Path to input heart rate CSV
        output_csv_file (str): Path to output CSV with hr_id
    """
    # Load the heart rate CSV
    hr_df = pd.read_csv(hr_csv_file)

    # Add hr_id column starting from 0
    hr_df['hr_id'] = range(len(hr_df))

    # Reorder columns to have hr_id first
    columns = ['hr_id'] + [col for col in hr_df.columns if col != 'hr_id']
    hr_df = hr_df[columns]

    # Save to CSV
    hr_df.to_csv(output_csv_file, index=False)
    print(f"HR CSV with IDs saved to: {output_csv_file}")
    print(f"Total HR lines: {len(hr_df)}")
    print(f"HR ID range: 0 to {len(hr_df) - 1}")

    return hr_df

# Process both heart rate files



print("Processing hr_flattened_level0.csv:")
hr_df_0 = add_hr_id_to_hr_csv("hr_flattened_level0.csv", "hr_with_id_level0.csv")

print("\n" + "="*50 + "\n")

print("Processing hr_flattened_level1.csv:")
hr_df_1 = add_hr_id_to_hr_csv("hr_flattened_level1.csv", "hr_with_id_level1.csv")

print("\n" + "="*50 + "\n")

print("Processing hr_flattened_level2.csv:")
hr_df_1 = add_hr_id_to_hr_csv("hr_flattened_level2.csv", "hr_with_id_level2.csv")

print("\n" + "="*50 + "\n")

print("Processing hr_flattened_level3.csv:")
hr_df_1 = add_hr_id_to_hr_csv("hr_flattened_level3.csv", "hr_with_id_level3.csv")

print("\n" + "="*50 + "\n")



# Show sample of the results
print("\nSample of first file:")
print(hr_df_1.head())

print("\nSample of second file:")
print(hr_df_0.head())
# Out:
# Processing hr_flattened_level0.csv:
# HR CSV with IDs saved to: hr_with_id_level0.csv
# Total HR lines: 923
# HR ID range: 0 to 922
#
# ==================================================
#
# Processing hr_flattened_level1.csv:
# HR CSV with IDs saved to: hr_with_id_level1.csv
# Total HR lines: 1654
# HR ID range: 0 to 1653
#
# ==================================================
#
# Processing hr_flattened_level2.csv:
# HR CSV with IDs saved to: hr_with_id_level2.csv
# Total HR lines: 904
# HR ID range: 0 to 903
#
# ==================================================
#
# Processing hr_flattened_level3.csv:
# HR CSV with IDs saved to: hr_with_id_level3.csv
# Total HR lines: 508
# HR ID range: 0 to 507
#
# ==================================================
#
#
# Sample of first file:
#    hr_id  timestamp_s     average   rr_s
# 0      0        0.531  111.900000  0.531
# 1      1        1.062  112.200005  0.531
# 2      2        1.593  112.400000  0.531
# 3      3        2.116  113.100000  0.523
# 4      4        2.639  113.600000  0.523
#
# Sample of second file:
#    hr_id  timestamp_s  average   rr_s
# 0      0        0.984     61.2  0.984
# 1      1        1.952     61.4  0.968
# 2      2        2.928     61.4  0.976
# 3      3        3.912     61.3  0.984
# 4      4        4.857     62.0  0.945

# %% [markdown]
# Cell  7 : Joining imu and hr data by id

# %%
def join_aggregated_imu_with_hr_with_ids(aggregated_imu_csv, hr_with_id_csv, output_csv):
  """
  Joins aggregated IMU features with HR data that already has hr_id.
  Keeps the HR timestamp in the output. Fills missing IMU values with 0.
  Parameters:
      aggregated_imu_csv (str): Path to aggregated IMU CSV with hr_id
      hr_with_id_csv (str): Path to HR CSV with hr_id column
      output_csv (str): Path to save joined CSV
  """
  # Load both CSVs
  imu_agg_df = pd.read_csv(aggregated_imu_csv)

  # Fill NaN values with 0
  imu_agg_df = imu_agg_df.fillna(0)

  hr_df = pd.read_csv(hr_with_id_csv)

  print(f"Aggregated IMU data shape: {imu_agg_df.shape}")
  print(f"HR data shape: {hr_df.shape}")

  # Join on hr_id
  joined_df = pd.merge(imu_agg_df, hr_df, on='hr_id', how='inner')

  print(f"Joined data shape: {joined_df.shape}")

  # If there are duplicate timestamp columns, handle them
  if 'timestamp_s_x' in joined_df.columns and 'timestamp_s_y' in joined_df.columns:
      # Drop IMU timestamp (if it exists) and keep HR timestamp
      joined_df = joined_df.drop('timestamp_s_x', axis=1)
      joined_df = joined_df.rename(columns={'timestamp_s_y': 'hr_timestamp_s'})
  elif 'timestamp_s' in joined_df.columns:
      # Just rename the single timestamp column
      joined_df = joined_df.rename(columns={'timestamp_s': 'hr_timestamp_s'})

  # Reorder columns to have hr_id and hr_timestamp first
  columns_order = ['hr_id', 'hr_timestamp_s'] + \
                [col for col in joined_df.columns if col not in ['hr_id', 'hr_timestamp_s']]
  joined_df = joined_df[columns_order]

  # Check for HR IDs that didn't match
  imu_hr_ids = set(imu_agg_df['hr_id'].unique())
  hr_hr_ids = set(hr_df['hr_id'].unique())
  matched_hr_ids = imu_hr_ids.intersection(hr_hr_ids)
  unmatched_hr_ids = imu_hr_ids - hr_hr_ids

  print(f"\n=== JOIN ANALYSIS ===")
  print(f"HR IDs in aggregated IMU: {len(imu_hr_ids)}")
  print(f"HR IDs in HR data: {len(hr_hr_ids)}")
  print(f"HR IDs successfully matched: {len(matched_hr_ids)}")
  print(f"HR IDs in IMU but not in HR: {len(unmatched_hr_ids)}")

  if unmatched_hr_ids:
      print(f"Unmatched HR IDs: {sorted(unmatched_hr_ids)[:10]}")

  # Save the joined CSV
  joined_df.to_csv(output_csv, index=False)
  print(f"\nSaved joined CSV to: {output_csv}")

  # Show sample of joined data
  print(f"\nSample of joined data (first 3 rows):")
  print(joined_df.head(3))

  return joined_df


# If you have HR files with IDs already, use this version:

print("Joining with HR files that have IDs:")
joined_agg_0 = join_aggregated_imu_with_hr_with_ids("imu_aggregated_features_level0.csv", "hr_with_id_level0.csv", "imu_agg_hr_joined_level0.csv")
joined_agg_1 = join_aggregated_imu_with_hr_with_ids("imu_aggregated_features_level1.csv", "hr_with_id_level1.csv", "imu_agg_hr_joined_level1.csv")
joined_agg_2 = join_aggregated_imu_with_hr_with_ids("imu_aggregated_features_level2.csv", "hr_with_id_level2.csv", "imu_agg_hr_joined_level2.csv")
joined_agg_2 = join_aggregated_imu_with_hr_with_ids("imu_aggregated_features_level3.csv", "hr_with_id_level3.csv", "imu_agg_hr_joined_level3.csv")
# Out:
# Joining with HR files that have IDs:
# Aggregated IMU data shape: (685, 33)
# HR data shape: (923, 4)
# Joined data shape: (685, 36)
#
# === JOIN ANALYSIS ===
# HR IDs in aggregated IMU: 685
# HR IDs in HR data: 923
# HR IDs successfully matched: 685
# HR IDs in IMU but not in HR: 0
#
# Saved joined CSV to: imu_agg_hr_joined_level0.csv
#
# Sample of joined data (first 3 rows):
#    hr_id  hr_timestamp_s  imu_line_count   ax_mean    ax_std    ax_min  \
# 0      0           0.984              50  4.902734  0.040123  4.800174
# 1      1           1.952              48  4.921514  0.038802  4.826496
# 2      2           2.928              49  4.883877  0.034966  4.814531
#
#      ax_max  ax_median   ay_mean    ay_std  ...  gy_max  gy_median   gz_mean  \
# 0  4.993999   4.903069 -8.621839  0.061099  ...    3.99     -2.100 -1.517600
# 1  5.003571   4.928194 -8.607440  0.054442  ...    2.66     -1.855 -0.898333
# 2  4.941355   4.883925 -8.639814  0.053915  ...    3.85     -1.960 -0.982857
#
#      gz_std  gz_min  gz_max  gz_median  fatigue_level  average   rr_s
# 0  0.315734   -2.73   -0.91      -1.54              0     61.2  0.984
# 1  0.368807   -1.68   -0.28      -0.84              0     61.4  0.968
# 2  0.268825   -1.47   -0.28      -0.98              0     61.4  0.976
#
# [3 rows x 36 columns]
# Aggregated IMU data shape: (1654, 33)
# HR data shape: (1654, 4)
# Joined data shape: (1654, 36)
#
# === JOIN ANALYSIS ===
# HR IDs in aggregated IMU: 1654
# HR IDs in HR data: 1654
# HR IDs successfully matched: 1654
# HR IDs in IMU but not in HR: 0
#
# Saved joined CSV to: imu_agg_hr_joined_level1.csv
#
# Sample of joined data (first 3 rows):
#    hr_id  hr_timestamp_s  imu_line_count   ax_mean    ax_std    ax_min  \
# 0      0           0.593              30  1.844055  0.931672  0.043072
# 1      1           1.225              32  1.046374  1.345706 -2.608270
# 2      2           1.865              32  0.965239  2.173784 -3.474503
#
#      ax_max  ax_median   ay_mean    ay_std  ...  gy_max  gy_median   gz_mean  \
# 0  4.201947   1.823396 -9.708188  1.624784  ...   64.96      9.520 -5.735333
# 1  2.668093   1.468049 -9.709075  2.566635  ...   59.15     10.255  4.130000
# 2  4.501060   1.371136 -9.639307  5.263037  ...   75.95     16.905  1.218438
#
#       gz_std  gz_min  gz_max  gz_median  fatigue_level    average   rr_s
# 0   5.358984  -18.13    2.94     -5.355              1  99.200005  0.593
# 1   7.788115  -11.76   15.75      4.585              1  97.900000  0.632
# 2  17.635285  -23.10   34.02      0.595              1  96.700005  0.640
#
# [3 rows x 36 columns]
# Aggregated IMU data shape: (904, 33)
# HR data shape: (904, 4)
# Joined data shape: (904, 36)
#
# === JOIN ANALYSIS ===
# HR IDs in aggregated IMU: 904
# HR IDs in HR data: 904
# HR IDs successfully matched: 904
# HR IDs in IMU but not in HR: 0
#
# Saved joined CSV to: imu_agg_hr_joined_level2.csv
#
# Sample of joined data (first 3 rows):
#    hr_id  hr_timestamp_s  imu_line_count   ax_mean    ax_std     ax_min  \
# 0      0           0.515              26 -2.336951  1.099358  -4.781030
# 1      1           1.046              27 -1.256809  1.135343  -2.943277
# 2      2           1.569              26 -1.101750  3.912739 -10.650834
#
#      ax_max  ax_median   ay_mean    ay_std  ...  gy_max  gy_median    gz_mean  \
# 0 -0.638907  -2.165582  9.440022  2.498388  ...   10.22    -25.725   0.086154
# 1  1.529068  -1.497960  9.617275  3.066230  ...   40.32     19.950  10.746296
# 2  4.515418   0.191433  9.263131  7.338249  ...   39.34     -5.740   2.237308
#
#       gz_std  gz_min  gz_max  gz_median  fatigue_level  average   rr_s
# 0  19.414909  -43.05   19.11      9.100              2    113.8  0.515
# 1  13.335793  -14.77   36.54     12.250              2    113.6  0.531
# 2  17.835379  -44.59   22.75      4.655              2    113.9  0.523
#
# [3 rows x 36 columns]
# Aggregated IMU data shape: (477, 33)
# HR data shape: (508, 4)
# Joined data shape: (477, 36)
#
# === JOIN ANALYSIS ===
# HR IDs in aggregated IMU: 477
# HR IDs in HR data: 508
# HR IDs successfully matched: 477
# HR IDs in IMU but not in HR: 0
#
# Saved joined CSV to: imu_agg_hr_joined_level3.csv
#
# Sample of joined data (first 3 rows):
#    hr_id  hr_timestamp_s  imu_line_count   ax_mean    ax_std    ax_min  \
# 0      0           0.531              27  0.532555  0.368696  0.002393
# 1      1           1.062              27  1.070693  1.168401 -0.234505
# 2      2           1.593              26  6.597984  1.856233  4.254590
#
#       ax_max  ax_median   ay_mean    ay_std  ...  gy_max  gy_median  \
# 0   1.174918   0.492939  9.701027  0.262069  ...   20.86      16.45
# 1   5.027500   0.655657  8.738457  0.788616  ...   31.99      12.39
# 2  10.435472   6.407011  6.364307  1.457071  ...   92.61      67.83
#
#      gz_mean     gz_std  gz_min  gz_max  gz_median  fatigue_level     average  \
# 0  16.626296   6.986967    6.51   29.26  18.130000              3  111.900000
# 1  25.817037  17.697705   -0.56   50.26  30.240000              3  112.200005
# 2  62.356539  14.748095   40.74   88.20  58.590002              3  112.400000
#
#     rr_s
# 0  0.531
# 1  0.531
# 2  0.531
#
# [3 rows x 36 columns]
